# %%
from bs4 import BeautifulSoup
import requests
from lxml import etree

# %%
headers ={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.162 Safari/537.36'}
r=requests.get('https://xueqiu.com/8427437484/111067016',headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="zh-Hans"><head><meta charset="UTF-8"><meta http-equiv="x-ua-compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="renderer" content="webkit"><meta name="keywords" content="雪球,实时行情,股票,基金,ETF,分级基金,理财,可转债,A股,创业板,新三板,美股,港股,开户,交易,炒股,证券,K线图,指数,价值投资,投资,社交网络"><meta name="description" content="雪球股票，聪明的投资者都在这里  - 雪球提供沪深港美股票实时行情、实战交流、实盘交易。"><meta name="format-detection" content="telephone=no"><link href="//assets.imedao.com/images/favicon.png" rel="icon" type="image/png"><link href="//assets.imedao.com/ugc/css/han-5d0ceb7c5c.css" rel="stylesheet"><link rel="stylesheet" href="//assets.imedao.com/ugc/css/component/index-86650bd8ef.css"><title>阿图尔的门徒: 对于茅台、美的、格力等优质企业的简单现金流估值分析 估值原则 1，采取静态自由现金流保守估值，假定公司不再成长，以过去三年的平均自由现金流计算投资回报率；投资回报率（ROI... - 雪球</title><script>window.HANS = true;</script><link href="//assets.imedao.com/ugc/css/article-631695fa6d.css" rel="stylesheet"><script>window.SNOWMAN_USER = {};</script><script
# ...

# %%
soup = BeautifulSoup(r.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
t=soup.get_text()

# %%
BeautifulSoup(t,'lxml').get_text()
# Out:
# '阿图尔的门徒: 对于茅台、美的、格力等优质企业的简单现金流估值分析 估值原则 1，采取静态自由现金流保守估值，假定公司不再成长，以过去三年的平均自由现金流计算投资回报率；投资回报率（ROI... - 雪球window.HANS = true;window.SNOWMAN_USER = {};window.SNB = {\n  staticDomain: \'https://assets.imedao.com/\'\n};Raven.config(\'https://679b450e5be84810a1f6d152e560aa38@sentry.xueqiu.com/78\').install()\nRaven.setUserContext({\n  id: SNOWMAN_USER.id || -1,\n  username: SNOWMAN_USER.screen_name || \'\',\n  ip_address: \'27.38.32.56\'\n});首页精华今日话题雪球访谈找人问答行情行情中心筛选器新股上市买什么交易A股交易港美股交易蛋卷基金私募中心没有账号？立即注册 \ue6f6登录阿图尔的门徒()来自雪球修改于23分钟前\ue6ff关注\t对于茅台、美的、格力等优质企业的简单现金流估值分析来自阿图尔的门徒的雪球原创专栏 估值原则1，采取静态自由现金流保守估值，假定公司不再成长，以过去三年的平均自由现金流计算投资回报率；投资回报率（ROI)=三年平均自由现金流/公司股票市值=每股静态自由现金/股价。（市值数据以2018.7.25收盘价为准）2，计算公司十年的“自由现金流/净利润”百分比，再采用该百分比乘以“最近三年净利润的平均数”，估算出“正常化”的自由现金流。3，设定买入估值门槛与卖出估值门槛：买入估值门槛：对优秀上市公司，一般静态自由现金流回报率不低于5%，最少4%。理由：一，长期无风险国债的回报率为3.5%左右，而优质公司债券的长期回报率在4%～5%。二，在公司静态自由现金流收益率可以提供与优质公司债券相仿的前提下，公司的成长性就为价值投资提供了安全边际与潜在的超额收益可能。卖出估值门槛：无论多优秀的上市公司，静态自由现金流回报率小于2%，都是需要评估减仓卖出的信号。理由：一，从过去几年货币基金的市场收益率来看，2%基本是货币基金的年化收
# ...

# %%
tree = etree.HTML(r.text)

# %%
s=tree.xpath('string(.)')

# %%
s
# Out:
# '阿图尔的门徒: 对于茅台、美的、格力等优质企业的简单现金流估值分析 估值原则 1，采取静态自由现金流保守估值，假定公司不再成长，以过去三年的平均自由现金流计算投资回报率；投资回报率（ROI... - 雪球window.HANS = true;window.SNOWMAN_USER = {};window.SNB = {\n  staticDomain: \'https://assets.imedao.com/\'\n};Raven.config(\'https://679b450e5be84810a1f6d152e560aa38@sentry.xueqiu.com/78\').install()\nRaven.setUserContext({\n  id: SNOWMAN_USER.id || -1,\n  username: SNOWMAN_USER.screen_name || \'\',\n  ip_address: \'27.38.32.56\'\n});首页精华今日话题雪球访谈找人问答行情行情中心筛选器新股上市买什么交易A股交易港美股交易蛋卷基金私募中心没有账号？立即注册 \ue6f6登录阿图尔的门徒()来自雪球修改于23分钟前\ue6ff关注\t对于茅台、美的、格力等优质企业的简单现金流估值分析来自阿图尔的门徒的雪球原创专栏 估值原则1，采取静态自由现金流保守估值，假定公司不再成长，以过去三年的平均自由现金流计算投资回报率；投资回报率（ROI)=三年平均自由现金流/公司股票市值=每股静态自由现金/股价。（市值数据以2018.7.25收盘价为准）2，计算公司十年的“自由现金流/净利润”百分比，再采用该百分比乘以“最近三年净利润的平均数”，估算出“正常化”的自由现金流。3，设定买入估值门槛与卖出估值门槛：买入估值门槛：对优秀上市公司，一般静态自由现金流回报率不低于5%，最少4%。理由：一，长期无风险国债的回报率为3.5%左右，而优质公司债券的长期回报率在4%～5%。二，在公司静态自由现金流收益率可以提供与优质公司债券相仿的前提下，公司的成长性就为价值投资提供了安全边际与潜在的超额收益可能。卖出估值门槛：无论多优秀的上市公司，静态自由现金流回报率小于2%，都是需要评估减仓卖出的信号。理由：一，从过去几年货币基金的市场收益率来看，2%基本是货币基金的年化收
# ...

# %%
len(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c71df1a6e151> in <module>()
# ----> 1 len(s)
#
# NameError: name 's' is not defined
