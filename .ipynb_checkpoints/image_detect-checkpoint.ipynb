# %%
from PIL import Image
im = Image.open('code.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=148x50 at 0x3D990F0>

# %%
import cv2

# %%
import requests
with open('code.jpg','wb') as f:
    res = requests.get('http://serv.gcis.nat.gov.tw/pub/kaptcha.jpg')
    f.write(res.content)
