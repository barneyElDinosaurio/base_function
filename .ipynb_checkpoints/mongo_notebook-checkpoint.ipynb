# %%
import pymongo
import pandas as pd
import json
from sqlalchemy import create_engine
import re
import redis

# %%
db = pymongo.MongoClient('10.18.6.26',port=27018)

# %%
DB_NAME = 'spider'
DOC_NAME = 'ent_history'
doc = db[DB_NAME][DOC_NAME]

# %%
ret  = doc.find({})

# %%
not_fetch = []
for each in ret:
    if each.get('counts')==-1:
        not_fetch.append(each.get('name'))

# %%
not_fetch
# Out:
# ['泌阳',
#  '永定',
#  '常熟',
#  '吴江',
#  '武进',
#  '新北',
#  '钟楼',
#  '天宁',
#  '邳州',
#  '新沂',
#  '睢宁',
#  '李一',
#  '熊沙杉',
#  '钟丁良',
#  '方礼林',
#  '邓超体',
#  '刘研兵',
#  '文婉',
#  '田达海',
#  '罗昭权',
#  '戴隆星',
#  '宋美香',
#  '辜泽江',
#  '倪浚淋',
#  '唐丹润',
#  '常润艳',
#  '储王强',
#  '杨成伟',
#  '栗玉秋',
#  '田俊喜',
#  '司明康',
#  '童优兰',
#  '郑海忠',
#  '毛学芹',
#  '雷渊武',
#  '何鸿淳',
#  '董士威',
#  '吕娇娜',
#  '周梅静',
#  '盛廷贵',
#  '韩均秀',
#  '赵翠娜',
#  '夏跃慧',
#  '邵钰尧',
#  '任海斌',
#  '练康丹',
#  '俞运财',
#  '麻津鑫',
#  '樊艺博',
#  '魏孟富',
#  '聂宁杰',
#  '谢思衍',
#  '薛增洪',
#  '张敬岩',
#  '郑树英',
#  '由广道',
#  '刘宗倬',
#  '石启文',
#  '胡腊民',
#  '方。',
#  '田战营',
#  '刘天福妹',
#  '冯平子',
#  '赵宋丽',
#  '谢凯月',
#  '杨曙明',
#  '喻昌俊',
#  '阳明',
#  '密山',
#  '虎林',
#  '鸡东',
#  '讷河',
#  '拜泉',
#  '靖宇',
#  '徐水',
#  '中山',
#  '东莞',
#  '零陵',
#  '鄂西',
#  '郧阳',
#  '荆沙',
#  '襄樊',
#  '沙市',
#  '惠民',
#  '龙溪',
#  '晋江',
#  '建阳',
#  '徽州',
#  '滁县',
#  '宿县',
#  '巢湖',
#  '淮阴',
#  '合江',
#  '乌鲁',
#  '中卫',
#  '固原',
#  '酒泉',
#  '平凉',
#  '张掖',
#  '武威',
#  '天水',
#  '白银',
#  '金昌',
#  '嘉峪',
#  '兰州',
#  '北京',
#  '天津',
#  '河北',
#  '山西',
#  '内蒙',
#  '辽宁',
#  '吉林',
#  '黑龙',
#  '上海',
#  '江苏',
#  '浙江',
#  '安徽',
#  '福建',
#  '江西',
#  '山东',
#  '河南',
#  '湖北',
#  '湖南',
#  '广东',
#  '广西',
#  '海南',
#  '重庆',
#  '四川',
#  '贵州',
#  '云南',
#  '西藏',
#  '陕西',
#  '甘肃',
#  '青海',
#  '宁夏',
#  '新疆',
#  '台湾',
#  '香港',
#  '澳门',
#  '石家',
#  '唐山',
#  '秦皇',
#  '邯郸',
#  '邢台',
#  '保定',
#  '张家',
#  '承德',
#  '沧州',
#  '廊坊',
#  '衡水',
#  '太原',
#  '大同',
#  '阳泉',
#  '长治',
#  '晋城',
#  '朔州',
#  '晋中',
#  '运城',
#  '忻州',
#  '临汾',
#  '吕梁',
#  '呼和',
#  '包头',
#  '乌海',
#  '赤峰',
#  '通辽',
#  '鄂尔',
#  '呼伦',
#  '巴彦',
#  '乌兰',
#  '兴安',
#  '锡林',
#  '阿拉',
#  '沈阳',
#  '大连',
#  '鞍山',
#  '抚顺',
#  '本溪',
#  '丹东',
#  '锦州',
#  '营口',
#  '阜新',
#  '辽阳',
#  '盘锦',
#  '铁岭',
#  '朝阳',
#  '葫芦',
#  '长春',
#  '四平',
#  '辽源',
#  '通化',
#  '白山',
#  '松原',
#  '白城',
#  '延边',
#  '哈尔',
#  '齐齐',
#  '鸡西',
#  '鹤岗',
#  '双鸭',
#  '大庆',
#  '伊春',
#  '佳木',
#  '七台',
#  '牡丹',
#  '黑河',
#  '绥化',
#  '大兴',
#  '南京',
#  '无锡',
#  '徐州',
#  '常州',
#  '苏州',
#  '南通',
#  '连云',
#  '淮安',
#  '盐城',
#  '扬州',
#  '镇江',
#  '泰州',
#  '宿迁',
#  '杭州',
#  '宁波',
#  '温州',
#  '嘉兴',
#  '湖州',
#  '绍兴',
#  '金华',
#  '衢州',
#  '舟山',
#  '台州',
#  '丽水',
#  '合肥',
#  '芜湖',
#  '蚌埠',
#  '淮南',
#  '马鞍',
#  '淮北',
#  '铜陵',
#  '安庆',
#  '黄山',
#  '滁州',
#  '阜阳',
#  '宿州',
#  '六安',
#  '亳州',
#  '池州',
#  '宣城',
#  '福州',
#  '厦门',
#  '莆田',
#  '三明',
#  '泉州',
#  '漳州',
#  '南平',
#  '龙岩',
#  '宁德',
#  '南昌',
#  '景德',
#  '萍乡',
#  '九江',
#  '新余',
#  '鹰潭',
#  '赣州',
#  '吉安',
#  '宜春',
#  '抚州',
#  '上饶',
#  '济南',
#  '青岛',
#  '淄博',
#  '枣庄',
#  '东营',
#  '烟台',
#  '潍坊',
#  '济宁',
#  '泰安',
#  '威海',
#  '日照',
#  '莱芜',
#  '临沂',
#  '德州',
#  '聊城',
#  '滨州',
#  '菏泽',
#  '郑州',
#  '开封',
#  '洛阳',
#  '平顶',
#  '安阳',
#  '鹤壁',
#  '新乡',
#  '焦作',
#  '濮阳',
#  '许昌',
#  '漯河',
#  '三门',
#  '南阳',
#  '商丘',
#  '信阳',
#  '周口',
#  '驻马',
#  '武汉',
#  '黄石',
#  '十堰',
#  '宜昌',
#  '襄阳',
#  '鄂州',
#  '荆门',
#  '孝感',
#  '荆州',
#  '黄冈',
#  '咸宁',
#  '随州',
#  '恩施',
#  '长沙',
#  '株洲',
#  '湘潭',
#  '衡阳',
#  '邵阳',
#  '岳阳',
#  '常德',
#  '益阳',
#  '郴州',
#  '永州',
#  '怀化',
#  '娄底',
#  '湘西',
#  '广州',
#  '韶关',
#  '深圳',
#  '珠海',
#  '汕头',
#  '佛山',
#  '江门',
#  '湛江',
#  '茂名',
#  '肇庆',
#  '惠州',
#  '梅州',
#  '汕尾',
#  '河源',
#  '阳江',
#  '清远',
#  '潮州',
#  '揭阳',
#  '云浮',
#  '南宁',
#  '柳州',
#  '桂林',
#  '梧州',
#  '北海',
#  '防城',
#  '钦州',
#  '贵港',
#  '玉林',
#  '百色',
#  '贺州',
#  '河池',
#  '来宾',
#  '崇左',
#  '海口',
#  '三亚',
#  '三沙',
#  '成都',
#  '自贡',
#  '攀枝',
#  '泸州',
#  '德阳',
#  '绵阳',
#  '广元',
#  '遂宁',
#  '内江',
#  '乐山',
#  '南充',
#  '眉山',
#  '宜宾',
#  '广安',
#  '达州',
#  '雅安',
#  '巴中',
#  '资阳',
#  '阿坝',
#  '甘孜',
#  '凉山',
#  '贵阳',
#  '六盘',
#  '遵义',
#  '安顺',
#  '毕节',
#  '铜仁',
#  '黔西',
#  '黔东',
#  '黔南',
#  '昆明',
#  '曲靖',
#  '玉溪',
#  '保山',
#  '昭通',
#  '丽江',
#  '普洱',
#  '临沧',
#  '楚雄',
#  '红河',
#  '文山',
#  '西双',
#  '大理',
#  '德宏',
#  '怒江',
#  '迪庆',
#  '拉萨',
#  '日喀',
#  '山南',
#  '那曲',
#  '阿里',
#  '西安',
#  '铜川',
#  '宝鸡',
#  '咸阳',
#  '渭南',
#  '延安',
#  '汉中',
#  '榆林',
#  '安康',
#  '商洛']

# %%
len(not_fetch)
# Out:
# 425

# %%
not_fetch.remove('北屯')

# %%
not_fetch
# Out:
# ['昆玉',
#  '可克',
#  '双河',
#  '北屯',
#  '二区',
#  '一区',
#  '米泉',
#  '陶乐',
#  '石炭',
#  '泌阳',
#  '凤翔',
#  '确山',
#  '永定',
#  '新北',
#  '钟楼',
#  '天宁',
#  '邳州',
#  '新沂',
#  '睢宁',
#  '李一',
#  '熊沙杉',
#  '宣武',
#  '吴江',
#  '栗玉秋',
#  '万秀',
#  '安西',
#  '弋阳',
#  '田俊喜',
#  '刘天福妹',
#  '冯平子',
#  '黄州',
#  '黎平',
#  '喻昌俊',
#  '白银',
#  '兰州',
#  '北京']

# %%
not_fetch_copy = list(not_fetch)

# %%
rets = doc.find({})
for each in rets:
    if each.get('name') in not_fetch:
        if each.get('crawl_count') is not None and each.get('crawl_count')>=0:
            not_fetch_copy.remove(each.get('name'))
            print('remove {}'.format(each.get('name')))
        print(each)
# Out:
# {'_id': ObjectId('5b9289694640d41d4870c57c'), 'name': '泌阳', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b9304354640d424bccc2d44'), 'name': '永定', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b959ee54640d40f5cd7998d'), 'name': '常熟', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b95b6424640d40f5cd79f9e'), 'name': '吴江', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b95ccd54640d40f5cd7a4d0'), 'name': '武进', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b95d2d94640d40f5cd7a57b'), 'name': '新北', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b95dbf14640d41b1c1baf01'), 'name': '钟楼', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b9600f14640d4181c2efc93'), 'name': '天宁', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b96062e4640d430bc172ebb'), 'name': '邳州', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b96072b4640d433b84319a0'), 'name': '新沂', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5b970d164640d407b0779378'), 'name': '睢宁', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5ba0a8554640d4448ce87a00'), 'name': '李一', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5
 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5badf3529dc6d613d42fd0fa'), 'name': '商洛', 'counts': -1, 'crawl_count': -1}
# {'_id': ObjectId('5bae56829dc6d627b17310bc'), 'name': '北京', 'counts': -999}
# {'_id': ObjectId('5bae65a29dc6d627b173177f'), 'name': '甘孜', 'counts': -999}
# {'_id': ObjectId('5bae65a29dc6d627b1731780'), 'name': '河池', 'counts': -999}
# {'_id': ObjectId('5bae664a9dc6d627b17317e7'), 'name': '苏州', 'counts': -999}
# {'_id': ObjectId('5bae82749dc6d627b173237a'), 'name': '建阳', 'counts': -999}
# {'_id': ObjectId('5bae82959dc6d627b173237b'), 'name': '普洱', 'counts': -999}
# {'_id': ObjectId('5bae82af9dc6d627b173237c'), 'name': '武汉', 'counts': -999}
# {'_id': ObjectId('5bae82b89dc6d627b173237d'), 'name': '常州', 'counts': -999}
# {'_id': ObjectId('5bae82ed9dc6d627b173237e'), 'name': '南宁', 'counts': -999}
# {'_id': ObjectId('5bae82fd9dc6d627b173237f'), 'name': '株洲', 'counts': -999}
# {'_id': ObjectId('5bae83099dc6d627b1732380'), 'name': '广元', 'counts': -999}
# {'_id': ObjectId('5bae832d9dc6d627b1732381'), 'name': '虎林', 'counts': -999}
# {'_id': ObjectId('5bae83389dc6d627b1732382'), 'name': '广安', 'counts': -999}
# {'_id': ObjectId('5bae833e9dc6d627b1732383'), 'name': '淮安', 'counts': -999}
# {'_id': ObjectId('5bae83449dc6d627b1732384'), 'name': '德州', 'counts': -999}
# {'_id': ObjectId('5bae83479dc6d627b1732385'), 'name': '昆明', 'counts': -999}
# {'_id': ObjectId('5bae83569dc6d627b1732386'), 'name': '四川', 'counts': -999}
# {'_id': ObjectId('5bae83619dc6d627b1732387'), 'name': '张家', 'counts': -999}
# {'_id': ObjectId('5bae839f9dc6d627b1732388'), 'name': '丽水', 'counts': -999}
# {'_id': ObjectId('5bae83bc9dc6d627b1732389'), 'name': '舟山', 'counts': -999}
# {'_id': ObjectId('5bae83cd9dc6d627b173238a'), 'name': '方。', 'counts': -999}
# {'_id': ObjectId('5bae83d29dc6d627b173238b'), 'name': '江西', 'counts': -999}
# {'_id': ObjectId('5bae83e79dc6d627b173238c'), 'name': '梧州', 'counts': -999}
# {'_id': ObjectId('5bae83f49dc6d627b173238d'), 'name': '阿里', 'counts': -999}
# {'_id': ObjectId('5bae84019dc6d627b173238e'), 'name': '汕尾', 'counts': -999}
# {'_id': ObjectId('5bae842e9dc6d627b173238f'), 'name': '金昌', 'counts': -999}
# {'_id': ObjectId('5bae843b9dc6d627b1732390'), 'name': '阳江', 'counts': -999}
# {'_id': ObjectId('5bae84439dc6d627b1732391'), 'name': '漯河', 'counts': -999}
# {'_id': ObjectId('5bae844c9dc6d627b1732392'), 'name': '鸡西', 'counts': -999}
# {'_id': ObjectId('5bae84549dc6d627b1732393'), 'name': '河北', 'counts': -999}
# {'_id': ObjectId('5bae84679dc6d627b1732394'), 'name': '延边', 'counts': -999}
# {'_id': ObjectId('5bae84879dc6d627b1732395'), 'name': '漳州', 'counts': -999}
# {'_id': ObjectId('5bae848a9dc6d627b1732396'), 'name': '宜春', 'counts': -999}
# {'_id': ObjectId('5bae84929dc6d627b1732397'), 'name': '七台', 'counts': -999}
# {'_id': ObjectId('5bae849f9dc6d627b1732398'), 'name': '贺州', 'counts': -999}
# {'_id': ObjectId('5bae84a79dc6d627b1732399'), 'name': '宣城', 'counts': -999}
# {'_id': ObjectId('5bae84b49dc6d627b173239a'), 'name': '日照', 'counts': -999}
# {'_id': ObjectId('5bae84ba9dc6d627b173239b'), 'name': '内江', 'counts': -999}
# {'_id': ObjectId('5bae84d59dc6d627b173239c'), 'name': '文婉', 'counts': -999}
# {'_id': ObjectId('5bae84e99dc6d627b173239d'), 'name': '黄石', 'counts': -999}
# {'_id': ObjectId('5bae84f99dc6d627b173239e'), 'name': '南充', 'counts': -999}
# {'_id': ObjectId('5bae84fb9dc6d627b173239f'), 'name': '信阳', 'counts': -999}
# {'_id': ObjectId('5bae85089dc6d627b17323a0'), 'name': '威海', 'counts': -999}
# {'_id': ObjectId('5bae85149dc6d627b17323a1'), 'name': '汉中', 'counts': -999}
# {'_id': ObjectId('5bae85229dc6d627b17323a2'), 'name': '东营', 'counts': -999}
# {'_id': ObjectId('5bae85459dc6d627b17323a3'), 'name': '衢州', 'counts': -999}
# {'_id': ObjectId('5bae85669dc6d627b17323a4'), 'name': '常熟', 'counts': -999}
# {'_id': ObjectId('5bae85739dc6d627b17323a5'), 'name': '中山', 'counts': -999}
# {'_id': ObjectId('5bae85799dc6d627b17323a6'), 'name': '江苏', 'counts': -999}
# {'_id': ObjectId('5bae85869dc6d627b17323a7'), 'name': '贵州', 'counts': -999}
# {'_id': ObjectId('5bae858a9dc6d627b17323a8'), 'name': '河南', 'counts': -999}
# {'_id': ObjectId('5bae85919dc6d627b17323a9'), 'name': '晋中', 'counts': -999}
# {'_id': ObjectId('5bae85959dc6d627b17323aa'), 'name': '三沙', 'counts': -999}
# {'_id': ObjectId('5bae85ba9dc6d627b17323ab'), 'name': '鹤岗', 'counts': -999}
# {'_id': ObjectId('5bae85d39dc6d627b17323ac'), 'name': '常德', 'counts': -999}
# {'_id': ObjectId('5bae85f79dc6d627b17323ad'), 'name': '马鞍', 'counts': -999}
# {'_id': ObjectId('5bae861d9dc6d627b17323ae'), 'name': '河源', 'counts': -999}
# {'_id': ObjectId('5bae862c9dc6d627b17323af'), 'name': '洛阳', 'counts': -999}
# {'_id': ObjectId('5bae864e9dc6d627b17323b0'), 'name': '阜新', 'counts': -999}
# {'_id': ObjectId('5bae866d9dc6d627b17323b1'), 'name': '潮州', 'counts': -999}
# {'_id': ObjectId('5bae86849dc6d627b17323b2'), 'name': '大兴', 'counts': -999}
# {'_id': ObjectId('5bae86979dc6d627b17323b3'), 'name': '秦皇', 'counts': -999}
# {'_id': ObjectId('5bae86aa9dc6d627b17323b4'), 'name': '盐城', 'counts': -999}
# {'_id': ObjectId('5bae86b59dc6d627b17323b5'), 'name': '柳州', 'counts': -999}
# {'_id': ObjectId('5bae86c79dc6d627b17323b6'), 'name': '黄山', 'counts': -999}
# {'_id': ObjectId('5bae86ca9dc6d627b17323b7'), 'name': '泉州', 'counts': -999}
# {'_id': ObjectId('5bae86dc9dc6d627b17323b8'), 'name': '安阳', 'counts': -999}
# {'_id': ObjectId('5bae86e39dc6d627b17323b9'), 'name': '连云', 'counts': -999}
# {'_id': ObjectId('5bae86e69dc6d627b17323ba'), 'name': '崇左', 'counts': -999}
# {'_id': ObjectId('5bae86ed9dc6d627b17323bb'), 'name': '荆州', 'counts': -999}
# {'_id': ObjectId('5bae86f89dc6d627b17323bc'), 'name': '郴州', 'counts': -999}
# {'_id': ObjectId('5bae870e9dc6d627b17323bd'), 'name': '凉山', 'counts': -999}
# {'_id': ObjectId('5bae87359dc6d627b17323be'), 'name': '佳木', 'counts': -999}
# {'_id': ObjectId('5bae87519dc6d627b17323bf'), 'name': '清远', 'counts': -999}
# {'_id': ObjectId('5bae87679dc6d627b17323c0'), 'name': '商洛', 'counts': -999}
# {'_id': ObjectId('5bae878d9dc6d627b17323c1'), 'name': '海口', 'counts': -999}
# {'_id': ObjectId('5bae87909dc6d627b17323c2'), 'name': '天水', 'counts': -999}
# {'_id': ObjectId('5bae87ba9dc6d627b17323c3'), 'name': '辽源', 'counts': -999}
# {'_id': ObjectId('5bae87cf9dc6d627b17323c4'), 'name': '平顶', 'counts': -999}
# {'_id': ObjectId('5bae87db9dc6d627b17323c5'), 'name': '贵港', 'counts': -999}
# {'_id': ObjectId('5bae87e29dc6d627b17323c6'), 'name': '甘肃', 'counts': -999}
# {'_id': ObjectId('5bae88059dc6d627b17323c7'), 'name': '临沂', 'counts': -999}
# {'_id': ObjectId('5bae88109dc6d627b17323c8'), 'name': '景德', 'counts': -999}
# {'_id': ObjectId('5bae88209dc6d627b17323c9'), 'name': '益阳', 'counts': -999}
# {'_id': ObjectId('5bae882d9dc6d627b17323ca'), 'name': '青岛', 'counts': -999}
# {'_id': ObjectId('5bae88469dc6d627b17323cb'), 'name': '淮南', 'counts': -999}
# {'_id': ObjectId('5bae88539dc6d627b17323cc'), 'name': '湖北', 'counts': -999}
# {'_id': ObjectId('5bae886e9dc6d627b17323cd'), 'name': '焦作', 'counts': -999}
# {'_id': ObjectId('5bae88819dc6d627b17323ce'), 'name': '芜湖', 'counts': -999}
# {'_id': ObjectId('5bae88859dc6d627b17323cf'), 'name': '九江', 'counts': -999}
# {'_id': ObjectId('5bae888f9dc6d627b17323d0'), 'name': '重庆', 'counts': -999}
# {'_id': ObjectId('5bae88a59dc6d627b17323d1'), 'name': '扬州', 'counts': -999}
# {'_id': ObjectId('5bae88a89dc6d627b17323d2'), 'name': '广州', 'counts': -999}
# {'_id': ObjectId('5bae88af9dc6d627b17323d3'), 'name': '香港', 'counts': -999}
# {'_id': ObjectId('5bae88b19dc6d627b17323d4'), 'name': '孝感', 'counts': -999}
# {'_id': ObjectId('5bae88c39dc6d627b17323d5'), 'name': '通辽', 'counts': -999}
# {'_id': ObjectId('5bae88cc9dc6d627b17323d6'), 'name': '怒江', 'counts': -999}
# {'_id': ObjectId('5bae88dd9dc6d627b17323d7'), 'name': '德宏', 'counts': -999}
# {'_id': ObjectId('5bae88ee9dc6d627b17323d8'), 'name': '龙岩', 'counts': -999}
# {'_id': ObjectId('5bae88f89dc6d627b17323d9'), 'name': '池州', 'counts': -999}
# {'_id': ObjectId('5bae89079dc6d627b17323da'), 'name': '山东', 'counts': -999}
# {'_id': ObjectId('5bae89179dc6d627b17323db'), 'name': '邯郸', 'counts': -999}
# {'_id': ObjectId('5bae89489dc6d627b17323dc'), 'name': '沧州', 'counts': -999}
# {'_id': ObjectId('5bae89549dc6d627b17323dd'), 'name': '密山', 'counts': -999}
# {'_id': ObjectId('5bae896e9dc6d627b17323de'), 'name': '郧阳', 'counts': -999}
# {'_id': ObjectId('5bae897a9dc6d627b17323df'), 'name': '乌海', 'counts': -999}
# {'_id': ObjectId('5bae89ae9dc6d627b17323e0'), 'name': '佛山', 'counts': -999}
# {'_id': ObjectId('5bae89b79dc6d627b17323e1'), 'name': '通化', 'counts': -999}
# {'_id': ObjectId('5bae89c89dc6d627b17323e2'), 'name': '浙江', 'counts': -999}
# ...
# {'_id': ObjectId('5bae8e819dc6d627b173241d'), 'name': '上饶', 'counts': -999}
# {'_id': ObjectId('5bae8e8e9dc6d627b173241e'), 'name': '阿坝', 'counts': -999}
# {'_id': ObjectId('5bae8e9a9dc6d627b173241f'), 'name': '宜昌', 'counts': -999}
# {'_id': ObjectId('5bae8eb39dc6d627b1732420'), 'name': '黑龙', 'counts': -999}
# {'_id': ObjectId('5bae8ec79dc6d627b1732421'), 'name': '沈阳', 'counts': -999}
# {'_id': ObjectId('5bae8eec9dc6d627b1732422'), 'name': '鹤壁', 'counts': -999}
# {'_id': ObjectId('5bae8ef09dc6d627b1732423'), 'name': '吕梁', 'counts': -999}
# {'_id': ObjectId('5bae8f019dc6d627b1732424'), 'name': '滨州', 'counts': -999}
# {'_id': ObjectId('5bae8f289dc6d627b1732425'), 'name': '哈尔', 'counts': -999}
# {'_id': ObjectId('5bae8f359dc6d627b1732426'), 'name': '云南', 'counts': -999}
# {'_id': ObjectId('5bae8f479dc6d627b1732427'), 'name': '文山', 'counts': -999}
# {'_id': ObjectId('5bae8f539dc6d627b1732428'), 'name': '保定', 'counts': -999}
# {'_id': ObjectId('5bae8f649dc6d627b1732429'), 'name': '铁岭', 'counts': -999}
# {'_id': ObjectId('5bae8f709dc6d627b173242a'), 'name': '黔西', 'counts': -999}
# {'_id': ObjectId('5bae8f829dc6d627b173242b'), 'name': '阜阳', 'counts': -999}
# {'_id': ObjectId('5bae8f9f9dc6d627b173242c'), 'name': '呼伦', 'counts': -999}
# {'_id': ObjectId('5bae8fac9dc6d627b173242d'), 'name': '新疆', 'counts': -999}
# {'_id': ObjectId('5bae8fb39dc6d627b173242e'), 'name': '宜宾', 'counts': -999}
# {'_id': ObjectId('5bae8fc89dc6d627b173242f'), 'name': '新余', 'counts': -999}
# {'_id': ObjectId('5bae8fd29dc6d627b1732430'), 'name': '宁波', 'counts': -999}
# {'_id': ObjectId('5bae8fea9dc6d627b1732431'), 'name': '郑州', 'counts': -999}
# {'_id': ObjectId('5bae90129dc6d627b1732432'), 'name': '盘锦', 'counts': -999}
# {'_id': ObjectId('5bae90289dc6d627b1732433'), 'name': '鸡东', 'counts': -999}
# {'_id': ObjectId('5bae90499dc6d627b1732434'), 'name': '广东', 'counts': -999}
# {'_id': ObjectId('5bae906a9dc6d627b1732435'), 'name': '包头', 'counts': -999}
# {'_id': ObjectId('5bae90819dc6d627b1732436'), 'name': '淄博', 'counts': -999}
# {'_id': ObjectId('5bae908d9dc6d627b1732437'), 'name': '荆门', 'counts': -999}
# {'_id': ObjectId('5bae90a19dc6d627b1732438'), 'name': '六安', 'counts': -999}
# {'_id': ObjectId('5bae90a89dc6d627b1732439'), 'name': '渭南', 'counts': -999}
# {'_id': ObjectId('5bae90b89dc6d627b173243a'), 'name': '中卫', 'counts': -999}
# {'_id': ObjectId('5bae90d39dc6d627b173243b'), 'name': '湖州', 'counts': -999}
# {'_id': ObjectId('5bae90e09dc6d627b173243c'), 'name': '咸阳', 'counts': -999}
# {'_id': ObjectId('5bae90ed9dc6d627b173243d'), 'name': '白山', 'counts': -999}
# {'_id': ObjectId('5bae90f19dc6d627b173243e'), 'name': '莆田', 'counts': -999}
# {'_id': ObjectId('5bae90f49dc6d627b173243f'), 'name': '日喀', 'counts': -999}
# {'_id': ObjectId('5bae90fe9dc6d627b1732440'), 'name': '韶关', 'counts': -999}
# {'_id': ObjectId('5bae91189dc6d627b1732441'), 'name': '驻马', 'counts': -999}
# {'_id': ObjectId('5bae91259dc6d627b1732442'), 'name': '石家', 'counts': -999}
# {'_id': ObjectId('5bae91359dc6d627b1732443'), 'name': '赤峰', 'counts': -999}
# {'_id': ObjectId('5bae91469dc6d627b1732444'), 'name': '随州', 'counts': -999}
# {'_id': ObjectId('5bae91539dc6d627b1732445'), 'name': '西藏', 'counts': -999}
# {'_id': ObjectId('5bae91609dc6d627b1732446'), 'name': '西双', 'counts': -999}
# {'_id': ObjectId('5bae91769dc6d627b1732447'), 'name': '徐水', 'counts': -999}
# {'_id': ObjectId('5bae91929dc6d627b1732448'), 'name': '聊城', 'counts': -999}
# {'_id': ObjectId('5bae91ad9dc6d627b1732449'), 'name': '衡水', 'counts': -999}
# {'_id': ObjectId('5bae91c49dc6d627b173244a'), 'name': '齐齐', 'counts': -999}
# {'_id': ObjectId('5bae91e19dc6d627b173244b'), 'name': '零陵', 'counts': -999}
# {'_id': ObjectId('5bae91fe9dc6d627b173244c'), 'name': '黄冈', 'counts': -999}
# {'_id': ObjectId('5bae920b9dc6d627b173244d'), 'name': '吉安', 'counts': -999}
# {'_id': ObjectId('5bae920d9dc6d627b173244e'), 'name': '宁夏', 'counts': -999}
# {'_id': ObjectId('5bae92129dc6d627b173244f'), 'name': '自贡', 'counts': -999}
# {'_id': ObjectId('5bae921c9dc6d627b1732450'), 'name': '鹰潭', 'counts': -999}
# {'_id': ObjectId('5bae92209dc6d627b1732451'), 'name': '济南', 'counts': -999}
# {'_id': ObjectId('5bae92309dc6d627b1732452'), 'name': '沙市', 'counts': -999}
# {'_id': ObjectId('5bae923c9dc6d627b1732453'), 'name': '榆林', 'counts': -999}
# {'_id': ObjectId('5bae923e9dc6d627b1732454'), 'name': '铜陵', 'counts': -999}
# {'_id': ObjectId('5bae924d9dc6d627b1732455'), 'name': '平凉', 'counts': -999}
# {'_id': ObjectId('5bae92509dc6d627b1732456'), 'name': '鄂州', 'counts': -999}
# {'_id': ObjectId('5bae92639dc6d627b1732457'), 'name': '合江', 'counts': -999}
# {'_id': ObjectId('5bae92719dc6d627b1732458'), 'name': '台州', 'counts': -999}
# {'_id': ObjectId('5bae92789dc6d627b1732459'), 'name': '毕节', 'counts': -999}
# {'_id': ObjectId('5bae92a99dc6d627b173245a'), 'name': '南京', 'counts': -999}
# {'_id': ObjectId('5bae92ad9dc6d627b173245b'), 'name': '乐山', 'counts': -999}
# {'_id': ObjectId('5bae92bb9dc6d627b173245c'), 'name': '嘉峪', 'counts': -999}
# {'_id': ObjectId('5bae92bf9dc6d627b173245d'), 'name': '厦门', 'counts': -999}
# {'_id': ObjectId('5bae92c39dc6d627b173245e'), 'name': '鞍山', 'counts': -999}
# {'_id': ObjectId('5bae92d59dc6d627b173245f'), 'name': '长沙', 'counts': -999}
# {'_id': ObjectId('5bae92e79dc6d627b1732460'), 'name': '揭阳', 'counts': -999}
# {'_id': ObjectId('5bae92f59dc6d627b1732461'), 'name': '忻州', 'counts': -999}
# {'_id': ObjectId('5bae93089dc6d627b1732462'), 'name': '岳阳', 'counts': -999}
# {'_id': ObjectId('5bae931d9dc6d627b1732463'), 'name': '巴彦', 'counts': -999}
# {'_id': ObjectId('5bae93209dc6d627b1732464'), 'name': '澳门', 'counts': -999}
# {'_id': ObjectId('5bae932d9dc6d627b1732465'), 'name': '菏泽', 'counts': -999}
# {'_id': ObjectId('5bae93459dc6d627b1732466'), 'name': '襄阳', 'counts': -999}
# {'_id': ObjectId('5bae93609dc6d627b1732467'), 'name': '攀枝', 'counts': -999}
# {'_id': ObjectId('5bae936e9dc6d627b1732468'), 'name': '铜仁', 'counts': -999}
# {'_id': ObjectId('5bae93769dc6d627b1732469'), 'name': '山南', 'counts': -999}
# {'_id': ObjectId('5bae93799dc6d627b173246a'), 'name': '枣庄', 'counts': -999}
# {'_id': ObjectId('5bae93929dc6d627b173246b'), 'name': '西安', 'counts': -999}
# {'_id': ObjectId('5bae93aa9dc6d627b173246c'), 'name': '晋江', 'counts': -999}
# {'_id': ObjectId('5bae93c59dc6d627b173246d'), 'name': '大理', 'counts': -999}
# {'_id': ObjectId('5bae93e19dc6d627b173246e'), 'name': '泰州', 'counts': -999}
# {'_id': ObjectId('5bae93e79dc6d627b173246f'), 'name': '阳泉', 'counts': -999}
# {'_id': ObjectId('5bae93eb9dc6d627b1732470'), 'name': '拜泉', 'counts': -999}
# {'_id': ObjectId('5bae93fd9dc6d627b1732471'), 'name': '钦州', 'counts': -999}
# {'_id': ObjectId('5bae940f9dc6d627b1732472'), 'name': '徽州', 'counts': -999}
# {'_id': ObjectId('5bae94289dc6d627b1732473'), 'name': '百色', 'counts': -999}
# {'_id': ObjectId('5bae94429dc6d627b1732474'), 'name': '保山', 'counts': -999}
# {'_id': ObjectId('5bae945d9dc6d627b1732475'), 'name': '酒泉', 'counts': -999}
# {'_id': ObjectId('5bae94789dc6d627b1732476'), 'name': '吴江', 'counts': -999}
# {'_id': ObjectId('5bae94959dc6d627b1732477'), 'name': '资阳', 'counts': -999}
# {'_id': ObjectId('5bae94b59dc6d627b1732478'), 'name': '朝阳', 'counts': -999}
# {'_id': ObjectId('5bae94d29dc6d627b1732479'), 'name': '巴中', 'counts': -999}
# {'_id': ObjectId('5bae94ee9dc6d627b173247a'), 'name': '杭州', 'counts': -999}
# {'_id': ObjectId('5bae95029dc6d627b173247b'), 'name': '阳明', 'counts': -999}
# {'_id': ObjectId('5bae950d9dc6d627b173247c'), 'name': '北海', 'counts': -999}
# {'_id': ObjectId('5bae95299dc6d627b173247d'), 'name': '嘉兴', 'counts': -999}
# {'_id': ObjectId('5bae95339dc6d627b173247e'), 'name': '绵阳', 'counts': -999}
# {'_id': ObjectId('5bae953d9dc6d627b173247f'), 'name': '黔南', 'counts': -999}
# {'_id': ObjectId('5bae95519dc6d627b1732480'), 'name': '珠海', 'counts': -999}
# {'_id': ObjectId('5bae95729dc6d627b1732481'), 'name': '宁德', 'counts': -999}
# {'_id': ObjectId('5bae958f9dc6d627b1732482'), 'name': '萍乡', 'counts': -999}
# {'_id': ObjectId('5bae95a79dc6d627b1732483'), 'name': '广西', 'counts': -999}
# {'_id': ObjectId('5bae95ba9dc6d627b1732484'), 'name': '安康', 'counts': -999}
# {'_id': ObjectId('5bae95d89dc6d627b1732485'), 'name': '遵义', 'counts': -999}
# {'_id': ObjectId('5bae95f69dc6d627b1732486'), 'name': '无锡', 'counts': -999}
# {'_id': ObjectId('5bae96149dc6d627b1732487'), 'name': '东莞', 'counts': -999}
# {'_id': ObjectId('5bae96259dc6d627b1732488'), 'name': '邵阳', 'counts': -999}
# {'_id': ObjectId('5bae962a9dc6d627b1732489'), 'name': '伊春', 'counts': -999}
# {'_id': ObjectId('5bae962f9dc6d627b173248a'), 'name': '咸宁', 'counts': -999}
# {'_id': ObjectId('5bae96339dc6d627b173248b'), 'name': '成都', 'counts': -999}
# {'_id': ObjectId('5bae963a9dc6d627b173248c'), 'name': '云浮', 'counts': -999}
# {'_id': ObjectId('5bae964e9dc6d627b173248d'), 'name': '大同', 'counts': -999}
# {'_id': ObjectId('5bae965d9dc6d627b173248e'), 'name': '乌鲁', 'counts': -999}
# {'_id': ObjectId('5bae967e9dc6d627b173248f'), 'name': '衡阳', 'counts': -999}
# {'_id': ObjectId('5bae96999dc6d627b1732490'), 'name': '张掖', 'counts': -999}
# {'_id': ObjectId('5bae96c09dc6d627b1732491'), 'name': '开封', 'counts': -999}
# {'_id': ObjectId('5bae96d39dc6d627b1732492'), 'name': '楚雄', 'counts': -999}
# {'_id': ObjectId('5bae96e89dc6d627b1732493'), 'name': '三亚', 'counts': -999}
# {'_id': ObjectId('5bae97049dc6d627b1732494'), 'name': '宿县', 'counts': -999}
# {'_id': ObjectId('5bae97129dc6d627b1732495'), 'name': '娄底', 'counts': -999}
# {'_id': ObjectId('5bae97369dc6d627b1732496'), 'name': '抚州', 'counts': -999}
# {'_id': ObjectId('5bae97439dc6d627b1732497'), 'name': '襄樊', 'counts': -999}
# {'_id': ObjectId('5bae974c9dc6d627b1732498'), 'name': '晋城', 'counts': -999}
# {'_id': ObjectId('5bae97529dc6d627b1732499'), 'name': '青海', 'counts': -999}
# {'_id': ObjectId('5bae976b9dc6d627b173249a'), 'name': '黑河', 'counts': -999}
# {'_id': ObjectId('5bae97819dc6d627b173249b'), 'name': '恩施', 'counts': -999}
# {'_id': ObjectId('5bae978e9dc6d627b173249c'), 'name': '安庆', 'counts': -999}
# {'_id': ObjectId('5bae97969dc6d627b173249d'), 'name': '邢台', 'counts': -999}
# {'_id': ObjectId('5bae979c9dc6d627b173249e'), 'name': '长治', 'counts': -999}
# {'_id': ObjectId('5bae97a49dc6d627b173249f'), 'name': '辽阳', 'counts': -999}
# {'_id': ObjectId('5bae97ab9dc6d627b17324a0'), 'name': '抚顺', 'counts': -999}
# {'_id': ObjectId('5bae97bb9dc6d627b17324a1'), 'name': '新乡', 'counts': -999}
# {'_id': ObjectId('5bae97cf9dc6d627b17324a2'), 'name': '蚌埠', 'counts': -999}
# {'_id': ObjectId('5bae97e29dc6d627b17324a3'), 'name': '宝鸡', 'counts': -999}
# {'_id': ObjectId('5bae97e89dc6d627b17324a4'), 'name': '朔州', 'counts': -999}
# {'_id': ObjectId('5bae98009dc6d627b17324a5'), 'name': '昭通', 'counts': -999}
# {'_id': ObjectId('5bae98149dc6d627b17324a6'), 'name': '上海', 'counts': -999}
# {'_id': ObjectId('5bae98429dc6d627b17324a7'), 'name': '湘潭', 'counts': -999}
# {'_id': ObjectId('5bae985f9dc6d627b17324a8'), 'name': '长春', 'counts': -999}
# {'_id': ObjectId('5bae98709dc6d627b17324a9'), 'name': '淮阴', 'counts': -999}
# {'_id': ObjectId('5bae987e9dc6d627b17324aa'), 'name': '茂名', 'counts': -999}
# {'_id': ObjectId('5bae98989dc6d627b17324ab'), 'name': '淮北', 'counts': -999}
# {'_id': ObjectId('5bae98b89dc6d627b17324ac'), 'name': '安徽', 'counts': -999}
# {'_id': ObjectId('5bae98ce9dc6d627b17324ad'), 'name': '滁州', 'counts': -999}
# {'_id': ObjectId('5bae98dd9dc6d627b17324ae'), 'name': '呼和', 'counts': -999}
# {'_id': ObjectId('5bae98eb9dc6d627b17324af'), 'name': '三明', 'counts': -999}
# {'_id': ObjectId('5bae98ef9dc6d627b17324b0'), 'name': '葫芦', 'counts': -999}
# {'_id': ObjectId('5bae98fb9dc6d627b17324b1'), 'name': '讷河', 'counts': -999}
# {'_id': ObjectId('5bae99089dc6d627b17324b2'), 'name': '大连', 'counts': -999}
# {'_id': ObjectId('5bae99199dc6d627b17324b3'), 'name': '湖南', 'counts': -999}
# {'_id': ObjectId('5bae99309dc6d627b17324b4'), 'name': '山西', 'counts': -999}
# {'_id': ObjectId('5bae993e9dc6d627b17324b5'), 'name': '辽宁', 'counts': -999}
# {'_id': ObjectId('5bae994f9dc6d627b17324b6'), 'name': '周口', 'counts': -999}
# {'_id': ObjectId('5bae99649dc6d627b17324b7'), 'name': '梅州', 'counts': -999}
# {'_id': ObjectId('5bae996f9dc6d627b17324b8'), 'name': '红河', 'counts': -999}
# {'_id': ObjectId('5bae998e9dc6d627b17324b9'), 'name': '来宾', 'counts': -999}
# {'_id': ObjectId('5bae99ae9dc6d627b17324ba'), 'name': '南阳', 'counts': -999}
# {'_id': ObjectId('5bae99bc9dc6d627b17324bb'), 'name': '铜川', 'counts': -999}
# {'_id': ObjectId('5bae99c89dc6d627b17324bc'), 'name': '湘西', 'counts': -999}
# {'_id': ObjectId('5bae99cb9dc6d627b17324bd'), 'name': '济宁', 'counts': -999}
# {'_id': ObjectId('5bae99cf9dc6d627b17324be'), 'name': '烟台', 'counts': -999}
# {'_id': ObjectId('5bae99e89dc6d627b17324bf'), 'name': '唐山', 'counts': -999}
# {'_id': ObjectId('5bae9a019dc6d627b17324c0'), 'name': '松原', 'counts': -999}
# {'_id': ObjectId('5bae9a1d9dc6d627b17324c1'), 'name': '雅安', 'counts': -999}
# {'_id': ObjectId('5bae9a299dc6d627b17324c2'), 'name': '鄂西', 'counts': -999}
# {'_id': ObjectId('5bae9a419dc6d627b17324c3'), 'name': '本溪', 'counts': -999}
# {'_id': ObjectId('5bae9a4c9dc6d627b17324c4'), 'name': '绍兴', 'counts': -999}
# {'_id': ObjectId('5bae9a549dc6d627b17324c5'), 'name': '固原', 'counts': -999}
# {'_id': ObjectId('5bae9a689dc6d627b17324c6'), 'name': '临沧', 'counts': -999}
# {'_id': ObjectId('5bae9a6a9dc6d627b17324c7'), 'name': '锡林', 'counts': -999}
# {'_id': ObjectId('5bae9a779dc6d627b17324c8'), 'name': '龙溪', 'counts': -999}
# {'_id': ObjectId('5bae9a829dc6d627b17324c9'), 'name': '遂宁', 'counts': -999}
# {'_id': ObjectId('5bae9a899dc6d627b17324ca'), 'name': '宿迁', 'counts': -999}
# {'_id': ObjectId('5bae9a949dc6d627b17324cb'), 'name': '濮阳', 'counts': -999}
# {'_id': ObjectId('5bae9aa79dc6d627b17324cc'), 'name': '临汾', 'counts': -999}
# {'_id': ObjectId('5bae9ac89dc6d627b17324cd'), 'name': '六盘', 'counts': -999}
# {'_id': ObjectId('5bae9ad99dc6d627b17324ce'), 'name': '营口', 'counts': -999}
# {'_id': ObjectId('5bae9b1a9dc6d627b17324cf'), 'name': '白城', 'counts': -999}
# {'_id': ObjectId('5bae9b339dc6d627b17324d0'), 'name': '镇江', 'counts': -999}
# {'_id': ObjectId('5bae9b719dc6d627b17324d1'), 'name': '十堰', 'counts': -999}
# {'_id': ObjectId('5bae9b829dc6d627b17324d2'), 'name': '安顺', 'counts': -999}
# {'_id': ObjectId('5bae9b919dc6d627b17324d3'), 'name': '桂林', 'counts': -999}
# {'_id': ObjectId('5bae9bb09dc6d627b17324d4'), 'name': '廊坊', 'counts': -999}
# {'_id': ObjectId('5bae9bc09dc6d627b17324d5'), 'name': '深圳', 'counts': -999}
# {'_id': ObjectId('5bae9be69dc6d627b17324d6'), 'name': '那曲', 'counts': -999}
# {'_id': ObjectId('5bae9bf39dc6d627b17324d7'), 'name': '肇庆', 'counts': -999}
# {'_id': ObjectId('5bae9bf79dc6d627b17324d8'), 'name': '赣州', 'counts': -999}
# {'_id': ObjectId('5bae9bfd9dc6d627b17324d9'), 'name': '惠民', 'counts': -999}
# {'_id': ObjectId('5bae9c159dc6d627b17324da'), 'name': '四平', 'counts': -999}
# {'_id': ObjectId('5bae9c2e9dc6d627b17324db'), 'name': '贵阳', 'counts': -999}
# {'_id': ObjectId('5bae9c5d9dc6d627b17324dc'), 'name': '太原', 'counts': -999}
# {'_id': ObjectId('5bae9c7a9dc6d627b17324dd'), 'name': '眉山', 'counts': -999}
# {'_id': ObjectId('5bae9c9d9dc6d627b17324de'), 'name': '兰州', 'counts': -999}
# {'_id': ObjectId('5bae9cc29dc6d627b17324df'), 'name': '白银', 'counts': -999}
# {'_id': ObjectId('5bae9cd79dc6d627b17324e0'), 'name': '喻昌俊', 'counts': -999}
# {'_id': ObjectId('5bae9cfb9dc6d627b17324e1'), 'name': '冯平子', 'counts': -999}
# {'_id': ObjectId('5bae9d0a9dc6d627b17324e2'), 'name': '刘天福妹', 'counts': -999}
# {'_id': ObjectId('5bae9d2a9dc6d627b17324e3'), 'name': '田俊喜', 'counts': -999}
# {'_id': ObjectId('5bae9d3b9dc6d627b17324e4'), 'name': '栗玉秋', 'counts': -999}
# {'_id': ObjectId('5bae9d529dc6d627b17324e5'), 'name': '熊沙杉', 'counts': -999}
# {'_id': ObjectId('5bae9d6c9dc6d627b17324e6'), 'name': '李一', 'counts': -999}
# {'_id': ObjectId('5bae9da09dc6d627b17324e7'), 'name': '睢宁', 'counts': -999}
# {'_id': ObjectId('5bae9dcf9dc6d627b17324e8'), 'name': '新沂', 'counts': -999}
# {'_id': ObjectId('5bae9de99dc6d627b17324e9'), 'name': '邳州', 'counts': -999}
# {'_id': ObjectId('5bae9e0f9dc6d627b17324ea'), 'name': '天宁', 'counts': -999}
# {'_id': ObjectId('5bae9e189dc6d627b17324eb'), 'name': '钟楼', 'counts': -999}
# {'_id': ObjectId('5bae9e249dc6d627b17324ec'), 'name': '新北', 'counts': -999}
# {'_id': ObjectId('5bae9e299dc6d627b17324ed'), 'name': '永定', 'counts': -999}
# {'_id': ObjectId('5bae9e3d9dc6d627b17324ee'), 'name': '泌阳', 'counts': -999}

# %%
len(not_fetch_copy)
# Out:
# 425

# %%
new_copy = list(not_fetch_copy)
for i in not_fetch_copy:
    if len(i)!=2:
        new_copy.remove(i)

# %%
len(new_copy)
# Out:
# 372

# %%
final_ret = list(set(new_copy))

# %%
len(final_ret)
# Out:
# 372

# %%
'天津' in final_ret
# Out:
# True

# %%
len(not_fetch_copy)
# Out:
# 408

# %%
rets = doc.find({})
for each in rets:
    if each.get('name') in not_fetch:
        if each.get('crawl_count') is not None:
            not_fetch_copy.remove(each.get('name'))
            print('remove {}'.format(each.get('name')))
#         print(each)
# Out:
# remove 昆玉
# remove 可克
# remove 双河
# remove 二区
# remove 一区
# remove 米泉
# remove 陶乐
# remove 石炭
# remove 安西
# remove 宣武
# remove 凤翔
# remove 黎平
# remove 万秀
# remove 黄州
# remove 确山
# remove 弋阳
# remove 吴江

# %%
not_fetch_copy
# Out:
# ['泌阳',
#  '永定',
#  '新北',
#  '钟楼',
#  '天宁',
#  '邳州',
#  '新沂',
#  '睢宁',
#  '李一',
#  '熊沙杉',
#  '栗玉秋',
#  '田俊喜',
#  '刘天福妹',
#  '冯平子',
#  '喻昌俊',
#  '白银',
#  '兰州',
#  '北京']

# %%
only_one = set(not_fetch_copy)

# %%
len(only_one)
# Out:
# 18

# %%
len(not_fetch_copy)
# Out:
# 18

# %%
r=redis.StrictRedis('10.18.6.26',db=3,decode_responses=True)

# %%
for i in final_ret:
    r.lpush('location_remain',i)

# %%
set_obj=set()
for each in ret:
#     print(each)
    set_obj.add(each.get('qrcode'))

# %%
len(set_obj)
# Out:
# 514

# %%
len(area_list2)
# Out:
# 34220

# %%
print(area_list2[0])
# Out:
# 昆玉

# %%
area_list=[]
for each in ret:
    area_list.append(each.get('iname')[:2])

# %%
len(area_list)
# Out:
# 178058

# %%
result2 = list(set(area_list))

# %%
len(result)
# Out:
# 1673

# %%
filename = '失信被执行人爬取关键词.xlsx'
df = pd.read_excel(filename)
# print(df.head())
result = df['行政区划前两字'].values.tolist()
r = redis.StrictRedis('10.18.4.211', decode_responses=True, db=12)
# for i in result:
#     r.lpush('location',i.strip())

# %%
len(result)
# Out:
# 3231

# %%
len(result2)
# Out:
# 1673

# %%
for item in result:
    if item not in result2:
        if item not in area_list2:
            r.lpush('location_remain',item)

# %%
df=pd.DataFrame(list(ret))

# %%
df.head()

# %%
len(df)

# %%
name_list =[]
for name,group in df.groupby('name'):
    print(name)
    name_list.append(name)

# %%
len(name_list)

# %%
len(list(set(name_list)))

# %%
new_df = df.drop_duplicates(['name','publish'])

# %%
df.shape

# %%
new_df.shape

# %%
DB_USER='root'
DB_PASS='123456z'
DB_HOST='localhost'
DB_PORT='3306'
DATABASE='db_parker'
engine = create_engine('mysql+pymysql://{}:{}@{}:{}/{}?charset=utf8'.format(DB_USER, DB_PASS, DB_HOST, DB_PORT, DATABASE))

# %%
del new_df['_id']

# %%
def remark(x):
    y=re.sub('条评价','',x)
    y=re.sub('\+','',y)
    y=re.sub('万','0000',y)
    y=re.sub('\.','',y)
    
    return y

# %%
new_df['remark']=new_df['remark'].map(remark)

# %%
new_df.head()

# %%
new_df['remark']=new_df['remark'].astype(int)

# %%
new_df.to_sql('jd_book',engine)

# %%
result=[]
for i in ret:
#     del i['_id']
    result.append(i)
df = pd.read_json(json.dumps(result))

# %%
df1= df[~df['data'].isnull()]
# df[(~df['data'].isnull()) & (~df['exists'].isnull()) ]

# %%
if not df.iloc[72]['data']:
    print('empty')

# %%
for i in range(len(df1)):
    if df1.iloc[i]['data'] :
        print(df1.iloc[i])
#     if not i['data']:
#         print(i)

# %%
# 转为df
ret = doc.find({})
df = pd.DataFrame(list(ret))
del df['_id']

# %%
df.head()
# Out:
#    counts  crawl_count name
# 0       0          0.0   昆玉
# 1       0          0.0   可克
# 2       0          0.0   双河
# 3      13         13.0   北屯
# 4       0          0.0   二区

# %%
len(df)
# Out:
# 35684

# %%
dup = df['name'].value_counts()>1

# %%
type(dup)
# Out:
# pandas.core.series.Series

# %%
dup
# Out:
# 苏州      True
# 甘孜      True
# 河池      True
# 建阳      True
# 吴江      True
# 舟山      True
# 咸宁      True
# 徐州      True
# 阿拉      True
# 宜春      True
# 聊城      True
# 河源      True
# 三沙      True
# 晋城      True
# 万秀      True
# 呼伦      True
# 周口      True
# 运城      True
# 沈阳      True
# 衢州      True
# 惠州      True
# 菏泽      True
# 汉中      True
# 盘锦      True
# 许昌      True
# 呼和      True
# 长治      True
# 南充      True
# 楚雄      True
# 贵港      True
#        ...
# 赵悦诚    False
# 和鑫楠    False
# 滕铖     False
# 柏春贵    False
# 霍景磊    False
# 丁福红    False
# 姜国滨    False
# 翟少恒    False
# 柯秦彬    False
# 廖俊开    False
# 原明凯    False
# 雷帅峰    False
# 张奇奔    False
# 蒋道庆    False
# 彭岩哇    False
# 周泳亮    False
# 陈志哲    False
# 庹宇     False
# 浦东     False
# 马巳玉    False
# 郑连余    False
# 李琼玺    False
# 宋卓高    False
# 罗泽雨    False
# 刘冠冬    False
# 高文珂    False
# 程仁天    False
# 龚克伟    False
# 单显马    False
# 鄂温     False
# Name: name, Length: 35283, dtype: bool

# %%
new_dup=dup[dup==True]

# %%
dup_list =new_dup.index.tolist()

# %%
df[df['name'].isin(dup_list)]
# Out:
#        counts  crawl_count  name
# 0           0          0.0    昆玉
# 1           0          0.0    可克
# 2           0          0.0    双河
# 3          13         13.0    北屯
# 4           0          0.0    二区
# 5           0          0.0    一区
# 6           3          3.0    米泉
# 7          10         10.0    陶乐
# 8           0          0.0    石炭
# 9          15         15.0    安西
# 205         7          7.0    宣武
# 509        17         17.0    凤翔
# 734        52         52.0    黎平
# 1084     -999          NaN    昆玉
# 1085     -999          NaN    可克
# 1086     -999          NaN    双河
# 1087     -999          NaN    北屯
# 1088     -999          NaN    二区
# 1089     -999          NaN    一区
# 1090     -999          NaN    米泉
# 1091     -999          NaN    陶乐
# 1092     -999          NaN    石炭
# 1103       74         74.0    万秀
# 1384        5          5.0    黄州
# 1454       -1         -1.0    泌阳
# 1455       64         64.0    确山
# 1456     -999          NaN    凤翔
# 1457     -999          NaN    确山
# 1738       86         86.0    弋阳
# 1841       -1         -1.0    永定
# ...       ...          ...   ...
# 35654    -999          NaN    深圳
# 35655    -999          NaN    那曲
# 35656    -999          NaN    肇庆
# 35657    -999          NaN    赣州
# 35658    -999          NaN    惠民
# 35659    -999          NaN    四平
# 35660    -999          NaN    贵阳
# 35661    -999          NaN    太原
# 35662    -999          NaN    眉山
# 35663    -999          NaN    兰州
# 35664    -999          NaN    白银
# 35665    -999          NaN   喻昌俊
# 35666    -999          NaN   冯平子
# 35667    -999          NaN  刘天福妹
# 35668    -999          NaN   田俊喜
# 35669    -999          NaN   栗玉秋
# 35670    -999          NaN   熊沙杉
# 35671    -999          NaN    李一
# 35672    -999          NaN    睢宁
# 35673    -999          NaN    新沂
# 35674    -999          NaN    邳州
# 35675    -999          NaN    天宁
# 35676    -999          NaN    钟楼
# 35677    -999          NaN    新北
# 35678    -999          NaN    永定
# 35679    -999          NaN    泌阳
# 35680    -999          NaN    甘孜
# 35681    -999          NaN    河池
# 35682    -999          NaN    苏州
# 35683    -999          NaN    建阳
#
# [797 rows x 3 columns]

# %%
new_df = df.drop_duplicates(['counts','crawl_count','name'])

# %%
len(new_df)
# Out:
# 35679

# %%
len(df)
# Out:
# 35684

# %%
person_df = df[df['name'].map(lambda x:len(x)>2)]

# %%
person_df[person_df['counts']==-1]
# Out:
#        counts  crawl_count  name
# 2166       -1         -1.0   熊沙杉
# 14040      -1         -1.0   钟丁良
# 14041      -1         -1.0   方礼林
# 14042      -1         -1.0   邓超体
# 14043      -1         -1.0   刘研兵
# 14045      -1         -1.0   田达海
# 14046      -1         -1.0   罗昭权
# 14049      -1         -1.0   戴隆星
# 14052      -1         -1.0   宋美香
# 14056      -1         -1.0   辜泽江
# 14059      -1         -1.0   倪浚淋
# 14062      -1         -1.0   唐丹润
# 14063      -1         -1.0   常润艳
# 14064      -1         -1.0   储王强
# 14073      -1         -1.0   杨成伟
# 14521      -1         -1.0   栗玉秋
# 19923      -1         -1.0   田俊喜
# 23135      -1         -1.0   司明康
# 23136      -1         -1.0   童优兰
# 23137      -1         -1.0   郑海忠
# 23138      -1         -1.0   毛学芹
# 23139      -1         -1.0   雷渊武
# 23140      -1         -1.0   何鸿淳
# 23141      -1         -1.0   董士威
# 23142      -1         -1.0   吕娇娜
# 23143      -1         -1.0   周梅静
# 23144      -1         -1.0   盛廷贵
# 23145      -1         -1.0   韩均秀
# 23146      -1         -1.0   赵翠娜
# 23147      -1         -1.0   夏跃慧
# 23148      -1         -1.0   邵钰尧
# 23149      -1         -1.0   任海斌
# 23150      -1         -1.0   练康丹
# 23151      -1         -1.0   俞运财
# 23152      -1         -1.0   麻津鑫
# 23153      -1         -1.0   樊艺博
# 23154      -1         -1.0   魏孟富
# 23155      -1         -1.0   聂宁杰
# 23156      -1         -1.0   谢思衍
# 23157      -1         -1.0   薛增洪
# 23158      -1         -1.0   张敬岩
# 23159      -1         -1.0   郑树英
# 23160      -1         -1.0   由广道
# 23161      -1         -1.0   刘宗倬
# 23162      -1         -1.0   石启文
# 23163      -1         -1.0   胡腊民
# 25363      -1         -1.0   田战营
# 31396      -1         -1.0  刘天福妹
# 31397      -1         -1.0   冯平子
# 34201      -1         -1.0   赵宋丽
# 34209      -1         -1.0   谢凯月
# 34216      -1         -1.0   杨曙明
# 34219      -1         -1.0   喻昌俊

# %%
doc_record = db[DB_NAME]['sx_ent']

# %%
ret_sx = doc_record.find({})

# %%
df_sx = pd.DataFrame(list(ret_sx))

# %%
len(df_sx)
# Out:
# 248861

# %%
del df_sx['_id']

# %%
df_sx.head()
# Out:
#    age areaName businessEntity             cardNum           caseCode  \
# 0    0       河南             柳源           072234156  (2018)豫0305执1264号
# 1    0       新疆            张俊选          32885711-2   （2018）新0106执恢77号
# 2    0       新疆            姜建忠  9165900539****834R   （2018）新2923执242号
# 3    0       山东             张淼  9165430156****313C  (2017)鲁1082执3017号
# 4    0       山东             张淼  9165430156****313C  (2017)鲁1082执3015号
#
#        courtName       disruptTypeName  \
# 0     洛阳市涧西区人民法院  有履行能力而拒不履行生效法律文书确定义务
# 1  乌鲁木齐市头屯河区人民法院  有履行能力而拒不履行生效法律文书确定义务
# 2        库车县人民法院                其他规避执行
# 3        荣成市人民法院             其他妨碍、抗拒执行
# 4        荣成市人民法院             其他妨碍、抗拒执行
#
#                                                 duty              gistId  \
# 0      向原告支付货款767766元、违约金230330元、受理费11477元、保全费5000元。     2017豫0305民初591号
# 1                          被执行人给付申请执行人欠款2869144.06元。  (2016)新0106民初1961号
# 2  被告北屯市嘉林装饰设计有限公司于本判决生效后十日内向原告寇先君赔偿医疗费、误工费、护理费、住...               民事判决书
# 3                                               给付货款    2016鲁1082民初5189号
# 4                                               给付货款    2016鲁1082民初5239号
#
#         gistUnit   ...    partyTypeName performance performedPart  \
# 0        涧西区人民法院   ...                1       全部未履行            暂无
# 1  乌鲁木齐市头屯河区人民法院   ...                1       全部未履行            暂无
# 2        库车县人民法院   ...                1       全部未履行            暂无
# 3        荣成市人民法院   ...              581       全部未履行            暂无
# 4        荣成市人民法院   ...              581       全部未履行            暂无
#
#    publishDate                                             qysler  \
# 0  2018年07月12日  [{'cardNum': '6523241986****0927', 'corporatio...
# 1  2018年06月06日  [{'cardNum': '6526011958****2216', 'corporatio...
# 2  2018年05月03日                                                 []
# 3  2017年11月05日  [{'cardNum': '1322311967****1818', 'corporatio...
# 4  2017年11月05日                                                 []
#
#        regDate sexy unperformPart urlcpws urltszb
# 0  2018年04月16日  NaN            暂无     NaN     NaN
# 1  2018年04月02日  NaN            暂无     NaN     NaN
# 2  2018年03月07日  NaN            暂无     NaN     NaN
# 3  2017年10月20日  NaN            暂无     NaN     NaN
# 4  2017年10月20日  NaN            暂无     NaN     NaN
#
# [5 rows x 22 columns]

# %%
no_dup_df = df_sx.drop_duplicates(['cardNum','caseCode','gistId','iname'])

# %%
len(no_dup_df)
# Out:
# 227752
