# %%
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
file = 'piaoxian1538026942.png'
img = cv2.imread(file)
plt.imshow(img)

# %%
kernel = np.ones((4,4),np.uint8)
erosion =
