# %%
import tushare as ts

# %%
code='300527'
df = ts.get_today_ticks(code)
# Out:
# [Getting data:]########

# %%
df.sort_values(by='volume',ascending=False).head(100)
# Out:
#          time  price pchange  change  volume   amount type
# 27   11:23:42  22.50   -3.06   -0.28    2000  4500000   卖盘
# 282  10:01:27  22.55   -2.84   -0.53    1500  3382500   卖盘
# 197  10:26:24  22.57   -2.76   -0.29    1500  3385500   卖盘
# 223  10:17:45  22.60   -2.63   -0.40    1500  3390000   卖盘
# 101  11:01:24  22.57   -2.76   -0.37    1500  3385500   卖盘
# 340  09:48:57  22.51   -3.02   -0.63    1000  2251000   卖盘
# 26   11:23:51  23.00   -0.90    0.50     600  1380000   买盘
# 406  09:37:57  23.50   +1.25    0.38     359   843650   买盘
# 193  10:26:39  23.19   -0.09    0.04     300   695700   买盘
# 196  10:26:27  23.15   -0.26    0.58     269   623430   买盘
# 100  11:01:27  23.10   -0.47    0.53     258   595980   买盘
# 462  09:30:03  23.30   +0.39    0.37     252   587160   买盘
# 25   11:24:03  23.10   -0.47    0.10     230   531300   买盘
# 219  10:18:00  23.15   -0.26    0.00     218   504670   卖盘
# 217  10:18:15  23.20   -0.04    0.05     165   382800   买盘
# ...
