# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(1,21).reshape(5,4),columns = ['one','two','three','four'])
df
# Out:
#    one  two  three  four
# 0    1    2      3     4
# 1    5    6      7     8
# 2    9   10     11    12
# 3   13   14     15    16
# 4   17   18     19    20

# %%
result_df = map(lambda x:(x['three'] - x['two']),df[df['four']>12])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-762807a35531> in <module>()
# ----> 1 result_df = map(lambda x:(x['three'] - x['two']),df[df['four']>12])
#
# <ipython-input-7-762807a35531> in <lambda>(x)
# ----> 1 result_df = map(lambda x:(x['three'] - x['two']),df[df['four']>12])
#
# TypeError: string indices must be integers, not str

# %%
df.loc[df['four'] >= 12, 'four'] = df[df['four'] >= 12]['four'] - df[df['four'] >= 12]['two']
df
# Out:
#    one  two  three  four
# 0    1    2      3     4
# 1    5    6      7     8
# 2    9   10     11     2
# 3   13   14     15     2
# 4   17   18     19     2

# %%
a=0.01
b=0.01
a==b
# Out:
# True
