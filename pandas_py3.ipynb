# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://crawler:Crawler@1234@10.18.4.211:3367/spider?charset=utf8')

# %%
def read_sql(table,engine,chunksize=None,return_generator=True):

        if chunksize is not None and chunksize<=0:
            chunksize=None
        result=pd.read_sql(table,engine,chunksize=chunksize)
        if return_generator:
            return result
        else:
            if chunksize is None:
                return result
            else:
                result=list(result)
                if len(result)==0:
                    return pd.DataFrame()
                else:
                    result=pd.concat(result,axis=0)
                    return result

# %%
ret = pd.read_sql('qgzjcs_jg_copy',con=engine)

# %%
ret.head()
# Out:
#    id institution_name credit_code institution_type  \
# 0   1       广西科文招标有限公司        None             None
# 1   2     国鼎和诚招标咨询有限公司        None             None
# 2   3   中外建工程设计与顾问有限公司        None             None
# 3   4  广西华诚达建设项目管理有限公司        None             None
# 4   5     广西启元建筑设计有限公司        None             None
#
#                                      institution_url contracts  \
# 0  http://222.218.31.5:889/epoint-web-zwdt/nxzjjg...       冼启怀
# 1  http://222.218.31.5:889/epoint-web-zwdt/nxzjjg...       谭桂娟
# 2  http://222.218.31.5:889/epoint-web-zwdt/nxzjjg...        李强
# 3  http://222.218.31.5:889/epoint-web-zwdt/nxzjjg...       罗瑞峰
# 4  http://222.218.31.5:889/epoint-web-zwdt/nxzjjg...       薛明东
#
#   contracts_phone quality_scope quality_level service_type  \
# 0     18107851956          None          None         None
# 1     15077597576          None          None         None
# 2     15077155179          None          None         None
# ...

# %%
ret=ret.set_index('id',drop=True)

# %%
len(ret)
# Out:
# 25457

# %%
ret=ret.drop_duplicates(['institution_name','institution_url'])

# %%
ret.to_sql('qgzjcs_jg_pd',con=engine,index='id')
