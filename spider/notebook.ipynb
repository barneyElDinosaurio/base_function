# %%
from template_spider import getContentPost

# %%
x,y = getContentPost()
# Out:
# <!doctype html>
# <html>
# <head id="ctl00_Head1"><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><title>
# 	广东省建设行业数据开放平台
# </title><link href="../css/main.css" rel="stylesheet" type="text/css" /><link href="../css/nyroModal.css" rel="stylesheet" type="text/css" />
#     <script src="http://113.108.219.40/Dop/script/jquery-1.7.2.min.js"></script>
#     <script src="http://113.108.219.40/Dop/script/jquery-scrolltofixed-min.js"></script>
#     <script src="http://113.108.219.40/Dop/script/echarts.min.js"></script>
#     <script src="http://113.108.219.40/Dop/script/jquery.smooth-scroll.js"></script>
#     <script src="http://113.108.219.40/Dop/script/Utility.js"></script>
#     <script src="http://113.108.219.40/Dop/script/jquery.nyroModal-1.5.5.pack.js"></script>
#
#
# </head>
# <body>
#     <form method="post" action="SafetyAccidentList.aspx" id="aspnetForm">
# <div class="aspNetHidden">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />
# ...

# %%
node = y.xpath('//div[@class="column-wrap"]/table')[0]

# %%
import re
for i in node.xpath('.//tr'):
#     print(i.xpath('.//td'))
#     print(len(i.xpath('.//td/text()')))
#     print(i.xpath('.//td/text()')[0])
    content = i.xpath('.//td/text()')[6]
    print(content)
#     print(','.join(content.strip().split(u'，')[1:]))
    print()
#     print(i.xpath('.//td')[0].xpath('.//text()'))
# Out:
# 监理单位项目总监：刘世斌
#
#
# 监理单位项目总监：苟东红
#
#
# 监理单位项目总监：陈宇
#
#
# 监理单位项目总监：魏敦武
#
#
# 监理单位项目总监：刘飞跃
#
#
# 监理单位项目总监：吕征舟
#
#
# 监理单位项目总监：王汉
#
#
# 监理单位项目总监：谷剑波
#
#
# 监理单位项目总监：杨庆辉
#
#
# 监理单位项目总监：关建刚
#
#
# 监理单位项目总监：王德洪
#
#
# 监理单位项目总监：李春
#
#
# 监理单位项目总监：张涛
#
#
# 监理单位项目总监：庞博
#
#
# 监理单位项目总监：何世明
#
#
# 监理单位项目总监：李亚炎
#
#
# 监理单位项目总监：操新胜
#
#
# 监理单位项目总监：耿天来
#
#
# 监理单位项目总监：容亮
#
#
# 监理单位项目总监：李桂凤
