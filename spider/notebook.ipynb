# %%
import requests
import re
import time
import random
from header_toolkit import getheader
from bs4 import BeautifulSoup
from lxml import etree

# %%
header = getheader()

# %%
header
# Out:
# {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#  'Accept-Encoding': 'gzip,deflate',
#  'Accept-Language': 'zh,en;q=0.9,en-US;q=0.8',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Content-Length': '21589',
#  'Content-Type': 'application/x-www-form-urlencoded',
#  'Cookie': 'UM_distinctid=1641b08da9a800-0e1bb87bdc335a-601a147a-1fa400-1641b08da9b2b9;ASP.NET_SessionId=aarvfbqgg2sbceof3d053moh;CNZZDATA1261062804=671075873-1529461922-%7C1530063505',
#  'Host': '113.108.219.40',
#  'Origin': 'http://113.108.219.40',
#  'Pragma': 'no-cache',
#  'Referer': 'http://113.108.219.40/Dop/Search/BldQuaReissueList.aspx',
#  'Upgrade-Insecure-Requests': '1',
#  'User-Agent': 'Mozilla/5.0(WindowsNT6.1;WOW64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/67.0.3396.99Safari/537.36'}

# %%
del header['Content-Length']
headers = header

# %%
headers
# Out:
# {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
#  'Accept-Encoding': 'gzip,deflate',
#  'Accept-Language': 'zh,en;q=0.9,en-US;q=0.8',
#  'Cache-Control': 'no-cache',
#  'Connection': 'keep-alive',
#  'Content-Type': 'application/x-www-form-urlencoded',
#  'Cookie': 'UM_distinctid=1641b08da9a800-0e1bb87bdc335a-601a147a-1fa400-1641b08da9b2b9;ASP.NET_SessionId=aarvfbqgg2sbceof3d053moh;CNZZDATA1261062804=671075873-1529461922-%7C1530063505',
#  'Host': '113.108.219.40',
#  'Origin': 'http://113.108.219.40',
#  'Pragma': 'no-cache',
#  'Referer': 'http://113.108.219.40/Dop/Search/BldQuaReissueList.aspx',
#  'Upgrade-Insecure-Requests': '1',
#  'User-Agent': 'Mozilla/5.0(WindowsNT6.1;WOW64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/67.0.3396.99Safari/537.36'}

# %%
session = requests.Session()

# %%
# 注销的
url = 'http://113.108.219.40/Dop/Search/QuaCancelList.aspx'

# %%
ua={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'}

# %%
s1 = session.get(url,headers=ua)

# %%
s_tree= etree.HTML(s1.text)
val=s_tree.xpath('//input[@id="__VIEWSTATE"]/@value')[0]
print(val)
# Out:
# ...

# %%
# p_url = "http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=qp6ClRc1WHL5N93H8Dn/ipNj6JbhnxHK"
r=requests.get(url,header)
response = etree.HTML(r.text)

# %%
s2= BeautifulSoup(s1.text)
# Out:
# c:\python3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\python3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
s2
# Out:
# <!DOCTYPE html>
# <html>
# <head id="ctl00_Head1"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	广东省建设行业数据开放平台
# </title><link href="../css/main.css" rel="stylesheet" type="text/css"/><link href="../css/nyroModal.css" rel="stylesheet" type="text/css"/>
# <script src="http://113.108.219.40/Dop/script/jquery-1.7.2.min.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery-scrolltofixed-min.js"></script>
# <script src="http://113.108.219.40/Dop/script/echarts.min.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery.smooth-scroll.js"></script>
# <script src="http://113.108.219.40/Dop/script/Utility.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery.nyroModal-1.5.5.pack.js"></script>
# </head>
# <body>
# <form action="QuaCancelList.aspx" id="aspnetForm" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <div class="aspNetHidden">
# <input id="__EVENTTARGET" name="__EVENTTARGET" type="hidden" value=""/>
# <input id="__EVENTARGUMENT" name="__EVENTARGUMENT" type="hidden" value=""/>
# </div>
# <div class="header">
# <div class="container">
# <div class="logo"><a href="http://113.108.219.40/Dop">数据开放平台</a></div>
# <div class="nav">
# <ul>
# <li><a href="http://113.108.219.40/Dop/BigData/BigDataWeb.aspx">行业大数据</a></li>
# <li><a class="current" href="http://113.108.219.40/Dop/Open/EnterpriseList.aspx">企业信息</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/PersonList.aspx">人员信息</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/ProjectList.aspx">项目信息</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/EnterpriseGoodList.aspx">诚信信息</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="titlecontainer">
# <div class="ln-nav">
# <div class="container">
# <h1>企业资质证书注销公告</h1>
# </div>
# </div>
# <div class="ln-search">
# <div class="container">
# <ul class="search-panel">
# <li class="search-col1">
# <span class="search-input">
# <input id="ctl00_TitlePlaceHolder1_txtOrgName" name="ctl00$TitlePlaceHolder1$txtOrgName" placeholder="企业名称" type="text"/>
# </span>
# <span class="search-input">
# <input id="ctl00_TitlePlaceHolder1_txtQuaCode" name="ctl00$TitlePlaceHolder1$txtQuaCode" placeholder="证书编号" type="text"/>
# </span>
# <span class="search-select">
# <select class="input-text" id="ctl00_TitlePlaceHolder1_ddlSLDW" name="ctl00$TitlePlaceHolder1$ddlSLDW">
# <option selected="selected" value="">请选择注销机构</option>
# <option value="000013338">中华人民共和国住房和城乡建设部</option>
# <option value="006939799">广东省住房和城乡建设厅</option>
# <option value="007482938">广州市市政园林局</option>
# <option value="007482946">广州市国土资源和房屋管理局</option>
# <option value="007482612">广州市住房和城乡建设委员会</option>
# <option value="696931785">广州市林业和园林局</option>
# <option value="355743196">广州市国土资源和规划委员会</option>
# <option value="007493389">广州市荔湾区住房和建设局</option>
# <option value="455360221">广州市国土资源和规划委员会荔湾区局</option>
# <option value="355773918">广州市越秀区国土资源和规划局</option>
# <option value="007496395">广州市越秀区建设和水务局</option>
# <option value="007499537">广州市海珠区国土资源和规划局</option>
# <option value="007499393">广州市海珠区住房和建设水务局</option>
# <option value="MB2C48922">广州市天河区住房和建设水务局</option>
# <option value="MB2C48834">广州市天河区国土资源和规划局</option>
# <option value="007502599">广州市白云区国土资源和规划局</option>
# <option value="MB2C69213">广州市白云区住房和建设局</option>
# <option value="347513788">广州开发区行政审批局</option>
# <option value="558372030">广州市黄埔区住房和建设局</option>
# <option value="455413717">广州市国土资源和规划委员会番禺区局</option>
# <option value="007523795">广州市番禺区住房和建设局</option>
# <option value="007026545">揭阳市城市规划局</option>
# <option value="007026537">揭阳市住房和城乡建设局</option>
# <option value="007027329">揭阳榕城区建设局</option>
# <option value="707759010">揭阳市揭东区住房和城乡规划建设局</option>
# <option value="007029455">揭西县住房和城乡建设局</option>
# <option value="007030181">揭西县城乡规划局</option>
# <option value="007036444">惠来县城镇建设管理局</option>
# <option value="007035652">惠来县建设局</option>
# <option value="303800187">揭阳大南海石化工业区城乡规划建设局</option>
# <option value="007028698">揭阳市普宁华侨管理区建设局</option>
# <option value="456023876">普宁市城市管理局</option>
# <option value="007032611">普宁市住房和城乡建设局</option>
# <option value="00717621X">云浮市规划编制委员会</option>
# <option value="551692832">云浮市住房和城乡建设局</option>
# <option value="007173617">云浮市云城区建设局</option>
# <option value="786454193">新兴县城乡建设局</option>
# <option value="456507459">新兴县城乡规划局</option>
# <option value="456511060">郁南县城乡规划建设管理局</option>
# <option value="737584127">郁南县发展改革和城乡建设局</option>
# <option value="007172542">云浮市云安区住房和城乡建设局</option>
# <option value="007172577">云浮市国土资源和城乡规划管理局云安分局</option>
# <option value="007184906">罗定市城乡建设规划局</option>
# <option value="007184121">罗定市城乡建设局</option>
# </select>
# </span>
# </li>
# <li class="search-col2">
# <span class="search-select">
# <select class="input-text" id="ctl00_TitlePlaceHolder1_ddlQuaType" name="ctl00$TitlePlaceHolder1$ddlQuaType">
# <option selected="selected" value="">请选择资质证书类别</option>
# <option value="104">建筑业企业资质</option>
# <option value="106">工程造价咨询企业资质</option>
# <option value="103">工程建设项目招标代理机构资格</option>
# <option value="105">工程监理企业资质</option>
# <option value="101">建设工程勘察企业资质</option>
# <option value="102">建设工程设计企业资质</option>
# <option value="107">城乡规划编制单位资质</option>
# <option value="108">房地产开发企业资质</option>
# <option value="109">物业服务企业资质</option>
# <option value="110">房地产估价机构资质</option>
# <option value="112">城市园林绿化企业资质</option>
# <option value="117">建设工程质量检测机构资质</option>
# </select>
# </span>
# <span class="search-select">
# <select class="input-text" id="ctl00_TitlePlaceHolder1_ddlIsCopy" name="ctl00$TitlePlaceHolder1$ddlIsCopy">
# <option selected="selected" value="">注销方式</option>
# <option value="40101">整本资质证注销</option>
# <option value="40102">部分资质项注销</option>
# </select>
# </span>
# <span class="search-chkcode">
# <input autocomplete="off" id="ctl00_TitlePlaceHolder1_txtCheckCode" name="ctl00$TitlePlaceHolder1$txtCheckCode" placeholder="验证码" type="text"/>
# <a href="javascript:void(0);" onclick="ResetCode();">
# <img alt="验证码" id="CheckCodeImage" src="" title="点击换一张验证码"/></a>
# <input id="ctl00_TitlePlaceHolder1_hidCheckCodeMark" name="ctl00$TitlePlaceHolder1$hidCheckCodeMark" type="hidden"/>
# </span>
# </li>
# <li class="search-col3">
# <input class="search-btn" id="ctl00_TitlePlaceHolder1_btnSearch" name="ctl00$TitlePlaceHolder1$btnSearch" type="submit" value="搜索"/>
# </li>
# </ul>
# </div>
# </div>
# <div class="wrapper-main">
# <div class="container">
# <div class="column-wrap">
a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','4')" style="margin-right:5px;">4</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','5')" style="margin-right:5px;">5</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','6')" style="margin-right:5px;">6</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','7')" style="margin-right:5px;">7</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','8')" style="margin-right:5px;">8</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','9')" style="margin-right:5px;">9</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','10')" style="margin-right:5px;">10</a><span style="margin-right:5px;"><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','11')">...</a></span><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','2')" style="margin-right:5px;">&gt;</a><a href="javascript:__doPostBack('ctl00$TitlePlaceHolder1$AspNetPager1','20')" style="margin-right:5px;">&gt;&gt;</a>
# </div>
# </div>
# <!-- AspNetPager V7.0.2 for VS2005 & VS2008 End -->
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#         if (!('placeholder' in document.createElement('input'))) {
#             $('input[placeholder],textarea[placeholder]').each(function () {
#                 var that = $(this),
#                 text = that.attr('placeholder');
#                 if (that.val() === "") {
#                     that.val(text).addClass('placeholder');
#                 }
#                 that.focus(function () {
#                     if (that.val() === text) {
#                         that.val("").removeClass('placeholder');
#                     }
#                 })
#                 .blur(function () {
#                     if (that.val() === "") {
#                         that.val(text).addClass('placeholder');
#                     }
#                 })
#                 .closest('form').submit(function () {
#                     if (that.val() === text) {
#                         that.val('');
#                     }
#                 });
#             });
#         }
#     </script>
# <script type="text/javascript">
#         function ResetCode() {
#             var url = "http://113.108.219.40/Dop/CheckCode.aspx?codemark=";
#             var r = Math.random() * 1000;
#             url = url + r;
#             document.getElementById("ctl00_TitlePlaceHolder1_hidCheckCodeMark").value = r;
#             document.getElementById("CheckCodeImage").src = url;
#             document.getElementById("ctl00_TitlePlaceHolder1_txtCheckCode").value = "";
#             document.getElementById("ctl00_TitlePlaceHolder1_txtCheckCode").focus();
#             return false;
#         }
#         $(function () {
#             ResetCode();
#         }());
#     </script>
# </div>
# <div class="maincontainer">
# </div>
# <div class="footer">
# <div class="footer-container">
# <ul class="inlineUL">
# <li class="footerColumn three-columns">
# <h2>其他网站</h2>
# <ul class="clear cBoth">
# <li> <a href="http://www.gdcic.net" target="_blank">广东建设信息网</a></li>
# <li> <a href="http://www.gdcic.gov.cn" target="_blank">广东省住房和城乡建设厅</a></li>
# <li> <a href="http://113.108.219.40/Approve" target="_blank">三库一平台管理信息服务系统</a></li>
# <li> <a href="http://113.108.219.40/IntoGD/" target="_blank">进粤企业和人员诚信信息登记平台</a></li>
# </ul>
# </li>
# <li class="footerColumn three-columns">
# <h2>联系方式</h2>
# <ul class="clear cBoth">
# <li>技术支持：020-87250708</li>
# </ul>
# </li>
# <li class="footerColumn three-columns">
# <h2>其他媒体</h2>
# <ul class="social-link">
# <li class="wx"><a class="nyroModal2" href="http://113.108.219.40/Dop/ShowWeixin.aspx" id="showWeixinModal" target="_blank">微信</a></li>
# <li class="wb"><a href="http://weibo.com/gdcic" target="_blank">微博</a></li>
# </ul>
# </li>
# </ul>
# <div class="copyright"> 指导：广东省住房和城乡建设厅         承办：广东省建设信息中心          <script type="text/javascript">var cnzz_protocol = (("https:" == document.location.protocol) ? " https://" : " http://"); document.write(unescape("%3Cspan id='cnzz_stat_icon_1261062804'%3E%3C/span%3E%3Cscript src='" + cnzz_protocol + "s95.cnzz.com/z_stat.php%3Fid%3D1261062804%26show%3Dpic' type='text/javascript'%3E%3C/script%3E"));</script></div>
# </div>
# </div>
# <script>
#             $(function () {
#                 $('.nyroModal').nyroModal({
#                     titleFromIframe: false,
#                     width: 1400,
#                     height: 800
#                 });
#             });
#             $(function () {
#                 $('.nyroModal2').nyroModal({
#                     titleFromIframe: false,
#                     width: 600,
#                     height: 500
#                 });
#             });
#         </script>
# <script type="text/javascript">
# //<![CDATA[
# var theForm = document.forms['aspnetForm'];
# if (!theForm) {
#     theForm = document.aspnetForm;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
# </script>
# </form>
# </body>
# </html>

# %%
response.xpath('//div[@id="base-info "]//div[@class="spec-item"]/h5/a/text()')[0].strip()
# response.xpath('//h5/text()')
# Out:
# '广东省第四建筑工程有限公司'

# %%
r=requests.get(url,header)
# print(r.text)
tree= etree.HTML(r.text)
val=tree.xpath('//input[@id="__VIEWSTATE"]/@value')[0]
print(val)
# Out:
# ...

# %%
# 找出每个部门的id
id_item =[]
for i in s_tree.xpath('//select[@name="ctl00$TitlePlaceHolder1$ddlSLDW"]/option')[1:]:
#     id_item.append()
        id_item.append(i.xpath('.//@value')[0])

# %%
len(id_item)
# Out:
# 259

# %%
import redis
r=redis.StrictRedis('localhost',db=2)

# %%
for i in id_item:
    r.set(i,1)

# %%
data = {
    '__VIEWSTATE':val,
    '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$AspNetPager1',
'__EVENTARGUMENT': '3',
'ctl00$ContentPlaceHolder1$txtPersonName':'', 
'ctl00$ContentPlaceHolder1$txtIdNum': ''}
r=requests.post(url,headers=headers,data=data)

# %%
soup = BeautifulSoup(r.text)
# Out:
# c:\python3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\python3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
tree= etree.HTML(r.text)

# %%
data = {
    '__VIEWSTATE':val,
    '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$AspNetPager1',
'__EVENTARGUMENT': '3',
'ctl00$ContentPlaceHolder1$txtPersonName':'', 
'ctl00$ContentPlaceHolder1$txtIdNum': ''}
r=requests.post(url,headers,data)

# %%
soup = BeautifulSoup(r.text)
# Out:
# c:\python3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\python3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head id="ctl00_Head1"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	广东省建设行业数据开放平台
# </title><link href="../css/main.css" rel="stylesheet" type="text/css"/><link href="../css/nyroModal.css" rel="stylesheet" type="text/css"/>
# <script src="http://113.108.219.40/Dop/script/jquery-1.7.2.min.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery-scrolltofixed-min.js"></script>
# <script src="http://113.108.219.40/Dop/script/echarts.min.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery.smooth-scroll.js"></script>
# <script src="http://113.108.219.40/Dop/script/Utility.js"></script>
# <script src="http://113.108.219.40/Dop/script/jquery.nyroModal-1.5.5.pack.js"></script>
# </head>
# <body>
# <form action="PersonPunishmentList.aspx" id="aspnetForm" method="post">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <div class="header">
# <div class="container">
# <div class="logo"><a href="http://113.108.219.40/Dop">数据开放平台</a></div>
# <div class="nav">
# <ul>
# <li><a href="http://113.108.219.40/Dop/BigData/BigDataWeb.aspx">行业大数据</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/EnterpriseList.aspx">企业信息</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/PersonList.aspx">人员信息</a></li>
# <li><a href="http://113.108.219.40/Dop/Open/ProjectList.aspx">项目信息</a></li>
# <li><a class="current" href="http://113.108.219.40/Dop/Open/EnterpriseGoodList.aspx">诚信信息</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="titlecontainer">
# </div>
# <div class="maincontainer">
# <div class="ln-nav">
# <div class="container">
# <ul class="tabs">
# <li><a class="ent-good" href="http://113.108.219.40/Dop/Open/EnterpriseGoodList.aspx"><i></i>
# <h3>企业良好行为</h3>
# </a></li>
# <li><a class="ln-entbad " href="http://113.108.219.40/Dop/Open/EnterprisePunishmentList.aspx"><i></i>
# <h3>企业不良行为</h3>
# </a></li>
# <li><a class="ln-backpay " href="http://113.108.219.40/Dop/Open/EnterpriseBackPayList.aspx"><i></i>
# <h3>企业欠薪投诉</h3>
# </a></li>
# <li><a class="person-good" href="http://113.108.219.40/Dop/Open/PersonGoodList.aspx"><i></i>
# <h3>人员良好行为</h3>
# </a></li>
# <li class="current"><a class="ln-perbad" href="#"><i></i>
# <h3>人员不良行为</h3>
# </a></li>
# <li><a class="ln-blackent " href="http://113.108.219.40/Dop/Open/EnterpriseBlackList.aspx"><i></i>
# <h3>企业黑名单</h3>
# </a></li>
# <li><a class="ln-blackper" href="http://113.108.219.40/Dop/Open/PersonBlackList.aspx"><i></i>
# <h3>人员黑名单</h3>
# </a></li>
# </ul>
# </div>
# </div>
# <div class="ln-search">
# <div class="container">
# <ul class="search-panel">
# <li class="search-col1"><span class="search-input">
# <input id="ctl00_ContentPlaceHolder1_txtPersonName" name="ctl00$ContentPlaceHolder1$txtPersonName" placeholder="姓名" type="text"/>
# </span></li>
# <li class="search-col2">
# <span class="search-input">
# <input id="ctl00_ContentPlaceHolder1_txtIdNum" name="ctl00$ContentPlaceHolder1$txtIdNum" placeholder="身份证号码" type="text"/>
# </span></li>
# <li class="search-col3">
# <input class="search-btn" id="ctl00_ContentPlaceHolder1_Button1" name="ctl00$ContentPlaceHolder1$Button1" type="submit" value="搜索"/>
# </li>
# </ul>
# </div>
# </div>
# <div class="wrapper-main">
# <div class="container">
# <div class="column-wrap">
# <table class="data-list">
# <tr>
# <th style="text-align: left;">人员姓名</th>
# <th width="30%">处罚文件编号</th>
# <th style="text-align: left;" width="40%">处罚机构</th>
# <th width="15%">处罚时间</th>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/Pers

# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1042" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=Gt2CiyB8hKtDlxQa6x+ivmOEl2dnjUt8" target="_blank">陈爱昌</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1036" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/IntoGDPersonInfo.aspx?idnum=S6L7QNnYXwCotNjQsx2lEQOiK5X8N21N" target="_blank">王功福</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1034" target="_blank">云建监罚决[2018]31号、云建监罚决[2018]32号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=Gt2CiyB8hKtDlxQa6x+ivmOEl2dnjUt8" target="_blank">陈爱昌</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1035" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/IntoGDPersonInfo.aspx?idnum=S6L7QNnYXwCotNjQsx2lEQOiK5X8N21N" target="_blank">王功福</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1033" target="_blank">云建监罚决[2018]31号、云建监罚决[2018]32号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=Gt2CiyB8hKtDlxQa6x+ivmOEl2dnjUt8" target="_blank">陈爱昌</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1032" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=Gt2CiyB8hKtDlxQa6x+ivmOEl2dnjUt8" target="_blank">陈爱昌</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1031" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# <tr>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonInfo.aspx?idnum=Gt2CiyB8hKtDlxQa6x+ivmOEl2dnjUt8" target="_blank">陈爱昌</a>
# </td>
# <td style="text-align: left;">
# <a href="http://113.108.219.40/Dop/Open/PersonPunishmentInfo.aspx?ID=1038" target="_blank">云建监罚决[2018]29号、云建监罚决[2018]30号</a>
# </td>
# <td style="text-align: left;"><span title="广州市白云区住房和建设局">广州市白云区住房和建设局</span></td>
# <td>2018.05.04</td>
# </tr>
# </table>
# <div class="pages">
# <!-- AspNetPager V7.0.2 for VS2005 & VS2008  Copyright:2003-2007 Webdiyer (www.webdiyer.com) -->
# <div id="ctl00_ContentPlaceHolder1_AspNetPager1">
# <div>
# 	找到符合条件的记录73条
# </div><div>
# <a disabled="disabled">&lt;&lt;</a><a disabled="disabled">&lt;</a><span class="current">1</span><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','2')">2</a><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','3')">3</a><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','4')">4</a><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','5')">5</a><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','2')">&gt;</a><a href="javascript:__doPostBack('ctl00$ContentPlaceHolder1$AspNetPager1','5')">&gt;&gt;</a>
# </div>
# </div>
# <!-- AspNetPager V7.0.2 for VS2005 & VS2008 End -->
# </div>
# </div>
# </div>
# </div>
# <script>
#         $(document).ready(function () {
#             $('ul.tabs a').smoothScroll({ offset: -85 });
#             $('.gotop').smoothScroll({ offset: -70 });
#         });
#     </script>
# <script>
#         $(document).ready(function () {
#             $('.ln-nav').scrollToFixed({
#                 preFixed: function () { $(this).addClass('header-fix'); },
#                 postFixed: function () { $(this).removeClass('header-fix'); }
#             });
#         });
#     </script>
# <script type="text/javascript">
#         if (!('placeholder' in document.createElement('input'))) {
#             $('input[placeholder],textarea[placeholder]').each(function () {
#                 var that = $(this),
#                 text = that.attr('placeholder');
#                 if (that.val() === "") {
#                     that.val(text).addClass('placeholder');
#                 }
#                 that.focus(function () {
#                     if (that.val() === text) {
#                         that.val("").removeClass('placeholder');
#                     }
#                 })
#                 .blur(function () {
#                     if (that.val() === "") {
#                         that.val(text).addClass('placeholder');
#                     }
#                 })
#                 .closest('form').submit(function () {
#                     if (that.val() === text) {
#                         that.val('');
#                     }
#                 });
#             });
#         }
#     </script>
# </div>
# <div class="footer">
# <div class="footer-container">
# <ul class="inlineUL">
# <li class="footerColumn three-columns">
# <h2>其他网站</h2>
# <ul class="clear cBoth">
# <li> <a href="http://www.gdcic.net" target="_blank">广东建设信息网</a></li>
# <li> <a href="http://www.gdcic.gov.cn" target="_blank">广东省住房和城乡建设厅</a></li>
# <li> <a href="http://113.108.219.40/Approve" target="_blank">三库一平台管理信息服务系统</a></li>
# <li> <a href="http://113.108.219.40/IntoGD/" target="_blank">进粤企业和人员诚信信息登记平台</a></li>
# </ul>
# </li>
# <li class="footerColumn three-columns">
# <h2>联系方式</h2>
# <ul class="clear cBoth">
# <li>技术支持：020-87250708</li>
# </ul>
# </li>
# <li class="footerColumn three-columns">
# <h2>其他媒体</h2>
# <ul class="social-link">
# <li class="wx"><a class="nyroModal2" href="http://113.108.219.40/Dop/ShowWeixin.aspx" id="showWeixinModal" target="_blank">微信</a></li>
# <li class="wb"><a href="http://weibo.com/gdcic" target="_blank">微博</a></li>
# </ul>
# </li>
# </ul>
# <div class="copyright"> 指导：广东省住房和城乡建设厅         承办：广东省建设信息中心          <script type="text/javascript">var cnzz_protocol = (("https:" == document.location.protocol) ? " https://" : " http://"); document.write(unescape("%3Cspan id='cnzz_stat_icon_1261062804'%3E%3C/span%3E%3Cscript src='" + cnzz_protocol + "s95.cnzz.com/z_stat.php%3Fid%3D1261062804%26show%3Dpic' type='text/javascript'%3E%3C/script%3E"));</script></div>
# </div>
# </div>
# <script>
#             $(function () {
#                 $('.nyroModal').nyroModal({
#                     titleFromIframe: false,
#                     width: 1400,
#                     height: 800
#                 });
#             });
#             $(function () {
#                 $('.nyroModal2').nyroModal({
#                     titleFromIframe: false,
#                     width: 600,
#                     height: 500
#                 });
#             });
#         </script>
# </form>
# </body>
# </html>

# %%
response = etree.HTML(r.text)
table = response.xpath('//div[@class="column-wrap"]/table/tr')
# tree.xpath('.//th')[0].xpath('.//text()').extract_first()

# %%
table[1].xpath('.//td')[0].xpath('.//a/@href')[0]
# Out:
# 'http://113.108.219.40/Dop/Open/IntoGDPersonInfo.aspx?idnum=lDIuwjYgO1K72StbNXQxRhl464GAUi6K'

# %%
import pandas as pd
import json
import pymongo
from sqlalchemy import create_engine
client = pymongo.MongoClient('localhost')
doc = client['punish']['person']
engine = create_engine('mysql+pymysql://root:123456z@localhost/spider?charset=utf8')
temp=[]

for i in doc.find({}):
    del i['_id']
    temp.append(i)
df = pd.read_json(json.dumps(temp))
df.to_sql('tb_person_test',con=engine,if_exists='replace')
# Out:
# c:\python3\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xD6\\xD0\\xB9\\xFA\\xB1\\xEA...' for column 'VARIABLE_VALUE' at row 480")
#   result = self._query(query)

# %%
data={
 '__VIEWSTATE':val,
    '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$AspNetPager1',
'__EVENTARGUMENT': '5',
'ctl00$ContentPlaceHolder1$txtOrgName': '',
'ctl00$ContentPlaceHolder1$txtQuaCode': '',
'ctl00$ContentPlaceHolder1$txtSerialNo': '',
'ctl00$ContentPlaceHolder1$ddlQuaType': '',
'ctl00$ContentPlaceHolder1$ddlIsCopy': '',
'ctl00$ContentPlaceHolder1$ddlSLDW': '006939799',
'ctl00$ContentPlaceHolder1$txtCheckCode': '',
'ctl00$ContentPlaceHolder1$hidCheckCodeMark': '182.69168552465166'}

# %%
h=headers
del h['Cookie']

# %%
p = session.post(url,h,data)

# %%
p.status_code
# Out:
# 200

# %%
p_tree = etree.HTML(p.text)

# %%
nodes = p_tree.xpath('//div[@class="column-wrap"]/table')[0]

# %%
for node in nodes[1:]:
    print(node.xpath('.//td')[0].xpath('.//text()')[0].strip())
# Out:
# 广东弘佳建设工程有限公司
# 广东弘佳建设工程有限公司
# 广东中凯工程管理咨询有限公司
# 佛山市华正工程咨询有限公司
# 佛山市华正工程咨询有限公司
# 东莞市丰盛园林工程有限公司
# 深圳市天鹏建设工程有限公司
# 雅建建设集团有限公司
# 雅建建设集团有限公司
# 雅建建设集团有限公司
# 雅建建设集团有限公司
# 国安建设投资发展（深圳）有限公司
# 国安建设投资发展（深圳）有限公司
# 深圳市宏润建筑劳务有限公司
# 深圳市宏润建筑劳务有限公司
