# %%
import requests
import re
from scrapy.selector import Selector

# %%
url = 'http://httpbin.org/cookies'
# cookies = {'':'1234567890'}
cookies=dict(cookies_are='working')
r = requests.get(url,cookies=cookies)
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %%
headers={
#     'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8', 
#          'Accept-Encoding': 'gzip,deflate', 
#          'Accept-Language': 'zh,en;q=0.9,en-US;q=0.8', 
#          'Cache-Control': 'max-age=0', 
#          'Cookie': '__jsluid=935b5677aab2ac59da7ee6872759d3ee;tlb_cookie=S172.16.12.115;__jsl_clearance=1533603478.727|0|F%2ByvqKhpyr%2FhRWCpPXC8WbwfDDw%3D;td_cookie=1674165418', 
#          'Host': 'hi.gsxt.gov.cn', 
#          'Proxy-Connection': 'keep-alive', 
#          'Upgrade-Insecure-Requests': '1', 
         'User-Agent': 'Mozilla/5.0(WindowsNT6.1;WOW64)AppleWebKit/537.36(KHTML,likeGecko)Chrome/67.0.3396.99Safari/537.36'}

# %%
url = 'http://www.gxqyxygs.gov.cn/EntInfo.jspx?id=YmVsbG9xcnBxenRvdG12ZW9q'
r = requests.get(url=url, headers=headers)

# %%
r.status_code
# Out:
# 404

# %%
r.history
# Out:
# []

# %%
r.text
# Out:
# '<!DOCTYPE html>\r\n<!--[if IE 8]> <html lang="zh-cn" class="ie8"> <![endif]-->\r\n<!--[if IE 9]> <html lang="zh-cn" class="ie9"> <![endif]-->\r\n<!--[if !IE]><!-->\r\n<html lang="zh-cn">\r\n<!--<![endif]-->\r\n<head>\r\n    <meta name="renderer" content="webkit">\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <meta charset="utf-8" />\r\n    \r\n    <title>广州市穗江医疗投资管理有限公司 - 广州市商事主体信息公示平台</title>\r\n    \r\n    <link href="/Content/bootstrap.css" rel="stylesheet" />\r\n    <link href="/Content/style.css" rel="stylesheet" />\r\n    <link href="/Content/app.css" rel="stylesheet" />\r\n    <link href="/Content/plugins.css" rel="stylesheet" />\r\n    <link href="/Content/ie8.css" rel="stylesheet" />\r\n    <link href="/Content/plugins/animate.css" rel="stylesheet" />\r\n    <link href="/Content/plugins/box-shadows.css" rel="stylesheet" />\r\n    <link href="/Content/validateCodePopup.css" rel="stylesheet" />\r\n\r\n    <link href="/Content/font-awesome.min.css" rel="stylesheet" />\r\n    <link href="/Content/fore-style.css" rel="stylesheet" />\r\n    <link href="/Content/line-icons.css" rel="stylesheet" />\r\n    \r\n    <script src="/Scripts/modernizr-2.6.2.js"></script>\r\n    <!--[if IE]>\r\n    <style type="text/css">\r\n        .col-md-3 {\r\n            width: 15%;\r\n        }\r\n        .col-md-9 {\r\n            width: 75%;\r\n        }\r\n    </style>\r\n    <![endif]-->\r\n    <style type="text/css">\r\n        .clear {\r\n            clear: both;\r\n        }\r\n        .vcode\r\n        {\r\n            width:80px;\r\n            height:43px;\r\n            margin-top:-4px;\r\n        }\r\n        #input_text\r\n        {\r\n            background-color:white;\r\n            border:1px solid #d5eafd;\r\n        }\r\n        .search-back\r\n        {\r\n            background-color:transparent;\r\n            height:43px;\r\n            margin-top:0px;\r\n            margin-bottom:0px;\r\n        }\r\n        .search-input\r\n        {\r\n            min-width:730px;\r\n            width:730px;\r\n        }\r\n        .search-cnt2\r\n        {\r\n            width:708px; height:43px; margin:0 auto; padding-left:60px;\r\n        }\r\n    </style>\r\n</head>\r\n<body>\r\n    <!-- Topbar Navigation -->\r\n    <div class="top-bar" id="top-bar">\r\n    <div class="inner">\r\n        <a class="top-login" href="/"></a>\r\n        <div class="pull-right">\r\n                    <a href="javascript:personLogin();" >用户登录</a>\r\n                    <div style="display:none;">\r\n                        <a id="loginLink2" href="http://ent.gzonline.gov.cn/" class="btn-u-sm bg-color-green">用户登录</a>\r\n                        <a class="btn-u-sm bg-color-green" href="/Account/Login" id="loginLink" style="display:none;">用户登录</a>\r\n                    </div>\r\n        </div>\r\n    </div>\r\n</div>\r\n\r\n<script type="text/javascript">\r\n\r\n    function personLogin() {\r\n    //    if (confirm("在本地网站个人中心登录或进入企业服务空间，点击确定是在本地网站个人中心登录，点击取消是进入企业服务空间")) {\r\n      //      document.getElementById("loginLink").click();\r\n        //}\r\n        //else {\r\n            document.getElementById("loginLink2").click();\r\n        //}\r\n    }\r\n\r\n</script>\r\n    <!-- End Topbar Navigation -->\r\n    <!--=== Header ===-->\r\n    <div class="header">\r\n        <div class="inner">\r\n            <a href="/" class="logo"></a>\r\n            <div class="search search-input">\r\n                <div class="search-cnt">\r\n        <div class="row" style="height:43px;">\r\n            <span><input autocomplete="off" class="search-text" id="keywords1" name="keywords1" placeholder="请输入名称/注册号/社会信用代码" type="text" value="" /></span>\r\n            <input class="search-btn" type="button" value="" onclick="openVcode(\'keywords1\');" />\r\n        </div>\r\n                </div>\r\n                <div class="search-cnt2">\r\n                        \r\n                        <span class="row"><span>平台提供搜索服务</span> < ...
