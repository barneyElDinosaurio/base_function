# %%
from requests_html import HTMLSession

# %%
session = HTMLSession()

# %%
i=1
while 1:
    r = session.get('http://30daydo.com')
    print(r.status_code)
    print('count {}'.format(i))
    i=i+1
# Out:
# 200
# count 1
# 200
# count 2
# 200
# count 3
# 200
# count 4
# 200
# count 5
# 200
# count 6
# 200
# count 7
# 200
# count 8
# 200
# count 9
# 200
# count 10
# 200
# count 11
# 200
# count 12
# 200
# count 13
# 200
# count 14
# 200
# count 15
# 200
# count 16
# 200
# count 17
# 200
# count 18
# 200
# count 19
# 200
# count 20
# 200
# count 21
# 200
# count 22
# 200
# count 23
# 200
# count 24
# 200
# count 25
# 200
# count 26
# 200
# count 27
# 200
# count 28
# 200
# count 29
# 200
# count 30
# 200
# count 31
# 200
# count 32
# 200
# count 33
# 200
# count 34
# 200
# count 35
# 200
# count 36
# 200
# count 37
# 200
# count 38
# 200
# count 39
# 200
# count 40
# 200
# count 41
# 200
# count 42
# 200
# count 43
# 200
# count 44
# 200
# count 45
# 200
# count 46
# 200
# count 47
# 200
# count 48
# 200
# count 49
# 200
# count 50
# 200
# count 51
# 200
# count 52
# 200
# count 53
# 200
# count 54
# 200
# count 55
# 200
# count 56
# 200
# count 57
# 200
# count 58
# 200
# count 59
# 200
# ...

# %%
r.html.links
# Out:
# {'http://30daydo.com',
#  'http://30daydo.com/',
#  'http://30daydo.com/account/register/',
#  'http://30daydo.com/article/262',
#  'http://30daydo.com/article/314',
#  'http://30daydo.com/article/315',
#  'http://30daydo.com/article/316',
#  'http://30daydo.com/article/317',
#  'http://30daydo.com/article/318',
#  'http://30daydo.com/article/320',
#  'http://30daydo.com/article/323',
#  'http://30daydo.com/article/324',
#  'http://30daydo.com/article/325',
#  'http://30daydo.com/article/326',
#  'http://30daydo.com/article/327',
#  'http://30daydo.com/article/328',
#  'http://30daydo.com/article/329',
#  'http://30daydo.com/article/330',
#  'http://30daydo.com/article/331',
#  'http://30daydo.com/article/332',
#  'http://30daydo.com/article/333',
#  'http://30daydo.com/article/334',
#  'http://30daydo.com/article/335',
#  'http://30daydo.com/article/336',
#  'http://30daydo.com/explore/',
#  'http://30daydo.com/explore/category-11',
#  'http://30daydo.com/explore/category-12',
# ...

# %%
type(r.html.absolute_links)
# Out:
# set

# %%
 from xpinyin import Pinyin

# %%
p =Pinyin()

# %%
p.get_pinyin(u'习近平,你好')
# Out:
# 'xi-jin-ping-,-ni-hao'
