# %%
import numpy as np
import matplotlib.pyplot as plt
size = 5
a = np.random.random(size)
b = np.random.random(size)
c = np.random.random(size)
d = np.random.random(size)
x = np.arange(size)

total_width, n = 0.8, 3     # 有多少个类型，只需更改n即可
width = total_width / n
x = x - (total_width - width) / 2

plt.bar(x, a,  width=width, label='a')
plt.bar(x + width, b, width=width, label='b')
plt.bar(x + 2 * width, c, width=width, label='c')
plt.legend()
plt.show()

# %%
import tushare as ts
df=df = ts.get_today_all()
# Out:
# [Getting data:]############################################################

# %%
df.head(10)
# Out:
#      code  name  changepercent  trade   open   high    low  settlement  \
# 0  603999  读者传媒          1.860   7.12   7.05   7.14   7.00        6.99
# 1  603998  方盛制药          0.000   9.43   0.00   0.00   0.00        9.43
# 2  603997  继峰股份         -0.940  10.54  10.65  10.66  10.53       10.64
# 3  603996  中新科技          1.145  16.79  16.60  16.90  16.60       16.60
# 4  603993  洛阳钼业          7.357   8.61   8.06   8.80   7.96        8.02
# 5  603991  至正股份          3.799  22.95  22.15  23.29  22.15       22.11
# 6  603990  麦迪科技          2.104  33.97  33.35  34.20  33.00       33.27
# 7  603989  艾华集团          1.864  36.06  35.76  36.27  35.11       35.40
# 8  603988  中电电机          0.000  27.60   0.00   0.00   0.00       27.60
# 9  603987   康德莱          1.916  11.17  11.01  11.24  11.01       10.96
#
#       volume  turnoverratio      amount      per     pb        mktcap  \
# 0    2279140        0.98921    16153889   24.552  2.459  4.101120e+05
# 1          0        0.00000           0   58.938  4.066  4.063731e+05
# 2    2663770        1.55776    28209071   17.864  4.026  6.721560e+05
# 3    1471351        1.42469    24635011   43.051  3.548  5.039518e+05
# 4  505632902        3.90338  4219532871  143.500  4.989  1.859695e+07
# 5     635700        3.39947    14534414   34.254  3.854  1.710578e+05
# 6     262300        0.43519     8835479   45.293  6.702  2.748941e+05
# 7     994300        1.17843    35614361   40.977  6.127  1.081800e+06
# 8          0        0.00000           0   92.000  3.355  3.312000e+05
# 9    1099165        0.57829    12246224   18.016  2.941  3.523409e+05
#
#             nmc
# 0  1.640448e+05
# 1  4.009605e+05
# 2  1.802340e+05
# 3  1.733987e+05
# 4  1.115316e+07
# 5  4.291650e+04
# 6  2.047440e+05
# 7  3.042562e+05
# 8  3.312000e+05
# 9  2.123098e+05

# %%
df=df[df['changepercent']<11]
plt.hist(df['changepercent'],bins=20,alpha=0.75,rwidth=0.75)
plt.show()
