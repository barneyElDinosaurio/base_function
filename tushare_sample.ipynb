# %%
import tushare as ts


conn=ts.get_apis()


df=ts.stock_pledged()


df.head(10)


df.sort_values('deals',ascending=False)


df.sort_values('p_ratio',ascending=False)


ds=ts.pledged_detail()


names=ds.groupby('name')


names


names['name']


counts=names['name'].count().sort_values(ascending=False)


counts.to_csv('pledged_count.csv')


import tushare as ts


bonds=ts.new_cbonds()


bonds


import pandas as pd


df=ts.get_k_data('300527',start='2018-01-01')


df


df['name']=u'华舟应急'


df.set_index('date',inplace=True)


df


s=pd.Series(u'华舟应急',df.index)


s


df.drop('high',axis=1,inplace=True)


df


ts.get_deposit_rate()


ts.get_loan_rate()


base_info = ts.get_stock_basics(),
current_prices = ts.get_today_all()


current_prices.head()


base_info.loc['000625']['bvps']


current_prices[current_prices['code']=='000625']['trade'].values[0]


count=0,
for i in current_prices['code']:,
    if base_info.loc[i]['bvps']>=current_prices[current_prices['code'] == i]['trade'].values[0]:,
        print(base_info.loc[i]['name'],)
        ,
        count=count+1,
print(count)


debt = ts.new_cbonds(default=0)


debt.to_csv('temp.csv',encoding='gbk')


debt.dropna(subset=['marketprice'])


df= ts.tick('123005',conn=conn,date='2018-03-16')


df


df= ts.get_realtime_quotes('300433')


float(df['price'].values[0])


for i in debt['scode']:,
    print(i)


bond=ts.quotes('123005',conn=conn)


bond


current=17.25,
convert=13.11,
value = current/convert*100


value


price=121.5,
(price - value)*1.00/value*100


basic=ts.get_stock_basics()


basic.reset_index()
