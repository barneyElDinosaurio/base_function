# %%
import requests

# %%
import jieba

string = '这个把手该换了，我不喜欢日本和服，别把手放在我的肩膀上，工信处女干事每月经过下属科室都要亲口交代24口交换机等技术性器件的安装工作'
result = jieba.lcut(string)
print(len(result), '/'.join(result))
# result
# Out:
# 38 这个/把手/该换/了/，/我/不/喜欢/日本/和服/，/别/把手/放在/我/的/肩膀/上/，/工信处/女干事/每月/经过/下属/科室/都/要/亲口/交代/24/口/交换机/等/技术性/器件/的/安装/工作

# %%
# url = 'http://gsxt.jxaic.gov.cn/ECPS/qyxxgsAction_initQyxyxxMain.action?qylx=9999&nbxh=20171130143323102572&qylxFlag=2&zch=360103610121489'
url='http://www.sdsszt.com/viewInfo.do?entityNo=18329d24-013b-1000-e001-36d50a066465'

# %%
import re
from scrapy.selector import Selector

def html_to_text(r):
    p = re.compile('<script.*?</script>', re.S)
    ret = re.sub(p, '', r)
    tree = Selector(text=ret)
    content = tree.xpath('string(.)').extract_first()
    brace_pattern = re.compile('\{.*\}', re.S)
    p2 = re.compile('\r\n', re.S)
    content = re.sub(p2, '', content)
    content = brace_pattern.sub('', content)
    return content

# %%
def download(url, retry=5):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:31.0) Gecko/20100101 Firefox/31.0'}
    for _ in range(retry):
        try:
            r = requests.get(url, headers=headers)
            if r.status_code == 200:
                r.encoding = 'utf8'
                return r
            else:
                continue
        except Exception as e:
            print(e)
    return None

# %%
r=download(url)

# %%
r.status_code
# Out:
# 200

# %%
content = html_to_text(r.text)

# %%
content
# Out:
# '            国家企业信用信息公示系统                                                                                                                                        国家企业信用信息公示系统                    华北 | 北京 天津 河北 山西 内蒙古                    东北 | 辽宁 吉林 黑龙江                    华东 | 上海 江苏 浙江 安徽 福建 江西 山东                    华南 | 广东 广西 海南                    华中 | 河南 湖北 湖南                    西南 | 重庆 四川 贵州 云南 西藏                    西北 | 陕西 甘肃 青海 宁夏 新疆                                                                                企业信用信息\xa0\xa0                \xa0\xa0经营异常名录\xa0\xa0                 \xa0\xa0严重违法失信企业名单                                                                    请输入企业名称、统一社会信用代码或注册号！                            确\xa0定                                                佛山市顺德区木景佳府家具有限公司                                存续                                                                                    注册号/统一社会信用代码：                           91440606058507795G                                
# ...

# %%
content = re.sub('\s','',content)

# %%
content
# Out:
# '            国家企业信用信息公示系统                                                                                                                                        国家企业信用信息公示系统                    华北 | 北京 天津 河北 山西 内蒙古                    东北 | 辽宁 吉林 黑龙江                    华东 | 上海 江苏 浙江 安徽 福建 江西 山东                    华南 | 广东 广西 海南                    华中 | 河南 湖北 湖南                    西南 | 重庆 四川 贵州 云南 西藏                    西北 | 陕西 甘肃 青海 宁夏 新疆                                                                                企业信用信息\xa0\xa0                \xa0\xa0经营异常名录\xa0\xa0                 \xa0\xa0严重违法失信企业名单                                                                    请输入企业名称、统一社会信用代码或注册号！                            确\xa0定                                                佛山市顺德区木景佳府家具有限公司                                存续                                                                                    注册号/统一社会信用代码：                           91440606058507795G                                
# ...

# %%
result_list = (jieba.lcut(content))

# %%
results=[]
for i in result_list:
    if re.search('\s',i):
        continue
    results.append(i)

# %%
results
# Out:
# ['国家',
#  '企业信用',
#  '信息',
#  '公示',
#  '系统',
#  '国家',
#  '企业信用',
#  '信息',
#  '公示',
#  '系统',
#  '华北',
#  '|',
#  '北京',
#  '天津',
#  '河北',
#  '山西',
#  '内蒙古',
#  '东北',
#  '|',
#  '辽宁',
#  '吉林',
#  '黑龙江',
#  '华东',
#  '|',
#  '上海',
#  '江苏',
#  '浙江',
#  '安徽',
#  '福建',
#  '江西',
#  '山东',
#  '华南',
#  '|',
#  '广东',
#  '广西',
#  '海南',
#  '华中',
#  '|',
#  '河南',
#  '湖北',
#  '湖南',
#  '西南',
#  '|',
#  '重庆',
#  '四川',
#  '贵州',
#  '云南',
#  '西藏',
#  '西北',
#  '|',
#  '陕西',
#  '甘肃',
#  '青海',
#  '宁夏',
#  '新疆',
#  '企业信用',
#  '信息',
#  '经营',
#  '异常',
#  '名录',
#  '严重',
#  '违法',
#  '失信',
#  '企业名单',
#  '请',
#  '输入',
#  '企业',
#  '名称',
#  '、',
#  '统一',
#  '社会',
#  '信用',
#  '代码',
#  '或',
#  '注册号',
#  '！',
#  '确',
#  '定',
#  '佛山市',
#  '顺德区',
#  '木景佳府',
#  '家具',
#  '有限公司',
#  '存续',
#  '注册号',
#  '/',
#  '统一',
#  '社会',
#  '信用',
#  '代码',
#  '：',
#  '91440606058507795G',
#  '法定代表',
#  '人',
#  '：',
#  '刘',
#  '学海',
#  '登记',
#  '机关',
#  '：',
#  '佛山市',
#  '顺德区',
#  '市场',
#  '监督',
#  '管理局',
#  '成立',
#  '日期',
#  '：',
# ...

# %%
fun=lambda x:re.sub('\s','',x)

# %%
fun(' h h ee adfa')
# Out:
# 'hheeadfa'

# %%
ret= map(fun,result_list)

# %%
ret

# %%
list(ret)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '广州',
#  '师成',
#  '教育',
#  '科技',
#  '有限公司',
#  '',
#  '-',
#  '',
#  '广州市',
#  '商事',
#  '主体',
#  '信息',
#  '公示',
#  '平台',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.',
#  'clear',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
result_list
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '广州',
#  '师成',
#  '教育',
#  '科技',
#  '有限公司',
#  ' ',
#  '-',
#  ' ',
#  '广州市',
#  '商事',
#  '主体',
#  '信息',
#  '公示',
#  '平台',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  'clear',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
# ...
